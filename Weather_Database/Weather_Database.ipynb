# %%
#Import the dependencies.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Generate a new set of 1,500 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lats_lngs = zip(lats, lngs)
lats_lngs

# %%
# Add the latitudes and longitudes in a list.
coordinates = list(lats_lngs)

# %%
# import the citipy module.
from citipy import citipy

# %%
#Create a list for holding the names of cities.
cities = []
#Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 603

# %%
# Import the requests library.
import requests

#Import the API key.
from config import weather_api_key

# %%
# Starting URL for weather map API call.
url="http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#Import the datetime module from the datetime library.
from datetime import datetime

# %%
#Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

#Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if(i % 50 ==0 and i>=50):
        set_count += 1
        record_count = 1
        
    #Create endpoint url for each city.
    city_url = url + "&q=" + city
        
    #log the url,record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
        
    #Add 1 to the record count.
    record_count += 1
        
    #Run an API request for each of the cities.
    try:
         #Parse the JSON and retrieve the data.
        city_weather = requests.get(city_url).json()
        #Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description=city_weather["weather"][0]["description"]
            
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        #Rain data
        try:
            city_rain = city_weather["rain"]["3h"]
            
        except:
            city_rain = 0.00 
            
        try:
            city_snow = city_weather["snow"]["3h"]
        except:
            city_snow = 0.00
            
            
        #Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                           "Lat": city_lat,
                             "Lng": city_lng,
                             "Max Temp": city_max_temp,
                             "Humidity": city_humidity,
                             "Cloudiness": city_clouds,
                             "Wind Speed": city_wind,                                                         
                             "Current Description":city_weather_description})
    #If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
#Indicate the data loading is complete.
print("------------------------------")
print("Data Retrieval Complete       ")
print("------------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | beloha
# Processing Record 2 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 3 of Set 1 | severo-kurilsk
# Processing Record 4 of Set 1 | esperance
# Processing Record 5 of Set 1 | bijie
# Processing Record 6 of Set 1 | castro
# Processing Record 7 of Set 1 | sorland
# Processing Record 8 of Set 1 | nikolskoye
# Processing Record 9 of Set 1 | husavik
# Processing Record 10 of Set 1 | yerbogachen
# Processing Record 11 of Set 1 | hermanus
# Processing Record 12 of Set 1 | akyab
# Processing Record 13 of Set 1 | punta arenas
# Processing Record 14 of Set 1 | vila velha
# Processing Record 15 of Set 1 | pochutla
# Processing Record 16 of Set 1 | saint george
# Processing Record 17 of Set 1 | jamestown
# Processing Record 18 of Set 1 | piopio
# Processing Record 19 of Set 1 | lapua
# Processing Record 20 of Set 1 | saskylakh
# Processing Record 21 of Set 1 | hobart
# Processing Record 22 of Set 1 | warqla
# City not found. Skipping...
# Processing Record 23 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 1 | albany
# Processing Record 25 of Set 1 | puerto ayora
# Processing Record 26 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 27 of Set 1 | mataura
# Processing Record 28 of Set 1 | rikitea
# Processing Record 29 of Set 1 | tiksi
# Processing Record 30 of Set 1 | diu
# Processing Record 31 of Set 1 | pacifica
# Processing Record 32 of Set 1 | clyde river
# Processing Record 33 of Set 1 | busselton
# Processing Record 34 of Set 1 | nalut
# Processing Record 35 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 36 of Set 1 | aksu
# Processing Record 37 of Set 1 | otjimbingwe
# Processing Record 38 of Set 1 | bredasdorp
# Processing Record 39 of Set 1 | saint-philippe
# Processing Record 40 of Set 1 | saint-leu
# Processing Record 41 of Set 1 | port alfred
# Processing Record 42 of Set 1 | pevek
# Processing Record 43 of Set 1 | bethel
# Processing Record 44 of Set 1 | bluff
# Processing Record 45 of Set 1 | avarua
# Processing Record 46 of Set 1 | jiexiu
# Processing Record 47 of Set 1 | tasiilaq
# Processing Record 48 of Set 1 | sao felix do xingu
# Processing Record 49 of Set 1 | haines junction
# Processing Record 50 of Set 1 | kilindoni
# Processing Record 1 of Set 2 | atar
# Processing Record 2 of Set 2 | brainerd
# Processing Record 3 of Set 2 | nizhniy baskunchak
# Processing Record 4 of Set 2 | atuona
# Processing Record 5 of Set 2 | moron de la frontera
# Processing Record 6 of Set 2 | butaritari
# Processing Record 7 of Set 2 | quepos
# Processing Record 8 of Set 2 | longyearbyen
# Processing Record 9 of Set 2 | mandalgovi
# Processing Record 10 of Set 2 | cherskiy
# Processing Record 11 of Set 2 | souillac
# Processing Record 12 of Set 2 | tezu
# Processing Record 13 of Set 2 | sola
# Processing Record 14 of Set 2 | ushuaia
# Processing Record 15 of Set 2 | baruun-urt
# Processing Record 16 of Set 2 | yellowknife
# Processing Record 17 of Set 2 | kavieng
# Processing Record 18 of Set 2 | te anau
# Processing Record 19 of Set 2 | luau
# Processing Record 20 of Set 2 | sao filipe
# Processing Record 21 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 22 of Set 2 | erenhot
# Processing Record 23 of Set 2 | mitsamiouli
# Processing Record 24 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 25 of Set 2 | oudtshoorn
# Processing Record 26 of Set 2 | kapaa
# Processing Record 27 of Set 2 | hilo
# Processing Record 28 of Set 2 | ahuimanu
# Processing Record 29 of Set 2 | vaini
# Processing Record 30 of Set 2 | walvis bay
# Processing Record 31 of Set 2 | san cristobal
# Processing Record 32 of Set 2 | bilma
# Processing Record 33 of Set 2 | glen allen
# Processing Record 34 of Set 2 | andenes
# Processing Record 35 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 36 of Set 2 | hithadhoo
# Processing Record 37 of Set 2 | kruisfontein
# Processing Record 38 of Set 2 | golden
# Processing Record 39 of Set 2 | hamilton
# Processing Record 40 of Set 2 | boulsa
# Processing Record 41 of Set 2 | airai
# Processing Record 42 of Set 2 | sakaiminato
# Processing Record 43 of Set 2 | olga
# Processing Record 44 of Set 2 | coruripe
# Processing Record 45 of Set 2 | benguela
# Processing Record 46 of Set 2 | katherine
# Processing Record 47 of Set 2 | port hardy
# Processing Record 48 of Set 2 | ilulissat
# Processing Record 49 of Set 2 | fortuna
# Processing Record 50 of Set 2 | maloy
# Processing Record 1 of Set 3 | chagda
# City not found. Skipping...
# Processing Record 2 of Set 3 | victoria
# Processing Record 3 of Set 3 | klaksvik
# Processing Record 4 of Set 3 | thompson
# Processing Record 5 of Set 3 | kloulklubed
# Processing Record 6 of Set 3 | nguiu
# City not found. Skipping...
# Processing Record 7 of Set 3 | launceston
# Processing Record 8 of Set 3 | arraial do cabo
# Processing Record 9 of Set 3 | avera
# Processing Record 10 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 11 of Set 3 | east london
# Processing Record 12 of Set 3 | herran
# Processing Record 13 of Set 3 | new norfolk
# Processing Record 14 of Set 3 | bengkulu
# Processing Record 15 of Set 3 | camacari
# Processing Record 16 of Set 3 | ziniare
# Processing Record 17 of Set 3 | keti bandar
# Processing Record 18 of Set 3 | kautokeino
# Processing Record 19 of Set 3 | dauphin
# Processing Record 20 of Set 3 | zhangjiakou
# Processing Record 21 of Set 3 | marsh harbour
# Processing Record 22 of Set 3 | margate
# Processing Record 23 of Set 3 | kudahuvadhoo
# Processing Record 24 of Set 3 | tigil
# Processing Record 25 of Set 3 | lilongwe
# Processing Record 26 of Set 3 | constitucion
# Processing Record 27 of Set 3 | binzhou
# Processing Record 28 of Set 3 | qaanaaq
# Processing Record 29 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 30 of Set 3 | nizwa
# Processing Record 31 of Set 3 | port said
# Processing Record 32 of Set 3 | eenhana
# Processing Record 33 of Set 3 | tuatapere
# Processing Record 34 of Set 3 | pemangkat
# Processing Record 35 of Set 3 | mahebourg
# Processing Record 36 of Set 3 | cidreira
# Processing Record 37 of Set 3 | luderitz
# Processing Record 38 of Set 3 | vardo
# Processing Record 39 of Set 3 | mar del plata
# Processing Record 40 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 41 of Set 3 | honiara
# Processing Record 42 of Set 3 | barrow
# Processing Record 43 of Set 3 | tuktoyaktuk
# Processing Record 44 of Set 3 | bargal
# City not found. Skipping...
# Processing Record 45 of Set 3 | ponta do sol
# Processing Record 46 of Set 3 | gat
# Processing Record 47 of Set 3 | araouane
# Processing Record 48 of Set 3 | motril
# Processing Record 49 of Set 3 | vao
# Processing Record 50 of Set 3 | lebu
# Processing Record 1 of Set 4 | mankato
# Processing Record 2 of Set 4 | yuzhno-sukhokumsk
# Processing Record 3 of Set 4 | pozo colorado
# Processing Record 4 of Set 4 | salinopolis
# Processing Record 5 of Set 4 | kushalgarh
# Processing Record 6 of Set 4 | panguipulli
# Processing Record 7 of Set 4 | rabo de peixe
# Processing Record 8 of Set 4 | shchigry
# Processing Record 9 of Set 4 | meyungs
# City not found. Skipping...
# Processing Record 10 of Set 4 | juneau
# Processing Record 11 of Set 4 | amga
# Processing Record 12 of Set 4 | byron bay
# Processing Record 13 of Set 4 | chuy
# Processing Record 14 of Set 4 | carnarvon
# Processing Record 15 of Set 4 | kodiak
# Processing Record 16 of Set 4 | okhotsk
# Processing Record 17 of Set 4 | dallas
# Processing Record 18 of Set 4 | maceio
# Processing Record 19 of Set 4 | armacao dos buzios
# City not found. Skipping...
# Processing Record 20 of Set 4 | eyl
# Processing Record 21 of Set 4 | portage
# Processing Record 22 of Set 4 | lac du bonnet
# Processing Record 23 of Set 4 | adrar
# Processing Record 24 of Set 4 | la orilla
# Processing Record 25 of Set 4 | sernovodsk
# Processing Record 26 of Set 4 | inverell
# Processing Record 27 of Set 4 | mezen
# Processing Record 28 of Set 4 | moron
# Processing Record 29 of Set 4 | sinnamary
# Processing Record 30 of Set 4 | mayya
# Processing Record 31 of Set 4 | wanaka
# Processing Record 32 of Set 4 | mariental
# Processing Record 33 of Set 4 | caravelas
# Processing Record 34 of Set 4 | balaka
# Processing Record 35 of Set 4 | murgab
# Processing Record 36 of Set 4 | kawalu
# Processing Record 37 of Set 4 | vavuniya
# Processing Record 38 of Set 4 | asau
# Processing Record 39 of Set 4 | cap malheureux
# Processing Record 40 of Set 4 | bani
# Processing Record 41 of Set 4 | kachikau
# City not found. Skipping...
# Processing Record 42 of Set 4 | sobolevo
# Processing Record 43 of Set 4 | yavoriv
# Processing Record 44 of Set 4 | provideniya
# Processing Record 45 of Set 4 | beidao
# Processing Record 46 of Set 4 | sorong
# Processing Record 47 of Set 4 | maryville
# Processing Record 48 of Set 4 | vila
# Processing Record 49 of Set 4 | tabou
# Processing Record 50 of Set 4 | gazli
# Processing Record 1 of Set 5 | seminole
# Processing Record 2 of Set 5 | toba tek singh
# Processing Record 3 of Set 5 | touros
# Processing Record 4 of Set 5 | pedasi
# Processing Record 5 of Set 5 | lagoa
# Processing Record 6 of Set 5 | kollam
# Processing Record 7 of Set 5 | oistins
# Processing Record 8 of Set 5 | upernavik
# Processing Record 9 of Set 5 | mancora
# Processing Record 10 of Set 5 | south sioux city
# Processing Record 11 of Set 5 | mount isa
# Processing Record 12 of Set 5 | dikson
# Processing Record 13 of Set 5 | port elizabeth
# Processing Record 14 of Set 5 | kalat
# Processing Record 15 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 16 of Set 5 | iquitos
# Processing Record 17 of Set 5 | piotrkow trybunalski
# Processing Record 18 of Set 5 | plettenberg bay
# Processing Record 19 of Set 5 | kavaratti
# Processing Record 20 of Set 5 | saldanha
# Processing Record 21 of Set 5 | cayeli
# Processing Record 22 of Set 5 | ribeira grande
# Processing Record 23 of Set 5 | deputatskiy
# Processing Record 24 of Set 5 | cape town
# Processing Record 25 of Set 5 | faya
# Processing Record 26 of Set 5 | pasighat
# Processing Record 27 of Set 5 | brenham
# Processing Record 28 of Set 5 | kupang
# Processing Record 29 of Set 5 | lewiston
# Processing Record 30 of Set 5 | itarema
# Processing Record 31 of Set 5 | asyut
# Processing Record 32 of Set 5 | caceres
# Processing Record 33 of Set 5 | batagay
# Processing Record 34 of Set 5 | urmary
# Processing Record 35 of Set 5 | frickenhausen
# Processing Record 36 of Set 5 | imeni lva tolstogo
# City not found. Skipping...
# Processing Record 37 of Set 5 | kaitangata
# Processing Record 38 of Set 5 | bonga
# Processing Record 39 of Set 5 | wagar
# Processing Record 40 of Set 5 | porto novo
# Processing Record 41 of Set 5 | palmer
# Processing Record 42 of Set 5 | rio gallegos
# Processing Record 43 of Set 5 | mao
# Processing Record 44 of Set 5 | samarai
# Processing Record 45 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 46 of Set 5 | monforte de lemos
# Processing Record 47 of Set 5 | ostrovnoy
# Processing Record 48 of Set 5 | comodoro rivadavia
# Processing Record 49 of Set 5 | daru
# Processing Record 50 of Set 5 | emba
# Processing Record 1 of Set 6 | kahului
# Processing Record 2 of Set 6 | umm kaddadah
# Processing Record 3 of Set 6 | katsuura
# Processing Record 4 of Set 6 | grootegast
# Processing Record 5 of Set 6 | seoul
# Processing Record 6 of Set 6 | hambantota
# Processing Record 7 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 8 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 9 of Set 6 | tortosa
# Processing Record 10 of Set 6 | piet retief
# Processing Record 11 of Set 6 | tshikapa
# Processing Record 12 of Set 6 | boyuibe
# Processing Record 13 of Set 6 | buraydah
# Processing Record 14 of Set 6 | dingle
# Processing Record 15 of Set 6 | miranorte
# City not found. Skipping...
# Processing Record 16 of Set 6 | waipawa
# Processing Record 17 of Set 6 | oum hadjer
# Processing Record 18 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 19 of Set 6 | port lincoln
# Processing Record 20 of Set 6 | kidal
# Processing Record 21 of Set 6 | biak
# Processing Record 22 of Set 6 | georgetown
# Processing Record 23 of Set 6 | nantucket
# Processing Record 24 of Set 6 | broome
# Processing Record 25 of Set 6 | noumea
# Processing Record 26 of Set 6 | yamada
# Processing Record 27 of Set 6 | dunedin
# Processing Record 28 of Set 6 | bad kissingen
# Processing Record 29 of Set 6 | saint-michel-des-saints
# Processing Record 30 of Set 6 | lhokseumawe
# Processing Record 31 of Set 6 | verkhnyaya inta
# Processing Record 32 of Set 6 | alofi
# Processing Record 33 of Set 6 | aklavik
# Processing Record 34 of Set 6 | lasa
# Processing Record 35 of Set 6 | berlevag
# Processing Record 36 of Set 6 | hasaki
# Processing Record 37 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 38 of Set 6 | rincon
# Processing Record 39 of Set 6 | naze
# Processing Record 40 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 41 of Set 6 | arman
# Processing Record 42 of Set 6 | leningradskiy
# Processing Record 43 of Set 6 | geraldton
# Processing Record 44 of Set 6 | papetoai
# Processing Record 45 of Set 6 | kutum
# Processing Record 46 of Set 6 | gorontalo
# Processing Record 47 of Set 6 | trat
# Processing Record 48 of Set 6 | nea kallikratia
# Processing Record 49 of Set 6 | torbay
# Processing Record 50 of Set 6 | yamasaki
# Processing Record 1 of Set 7 | ensley
# Processing Record 2 of Set 7 | kurumkan
# Processing Record 3 of Set 7 | dongsheng
# Processing Record 4 of Set 7 | namibe
# Processing Record 5 of Set 7 | vetluzhskiy
# Processing Record 6 of Set 7 | rozkishne
# Processing Record 7 of Set 7 | kaseda
# Processing Record 8 of Set 7 | vanimo
# Processing Record 9 of Set 7 | mehamn
# Processing Record 10 of Set 7 | pyapon
# Processing Record 11 of Set 7 | olafsvik
# Processing Record 12 of Set 7 | bathsheba
# Processing Record 13 of Set 7 | macau
# Processing Record 14 of Set 7 | lerwick
# Processing Record 15 of Set 7 | sidi ali
# Processing Record 16 of Set 7 | praia da vitoria
# Processing Record 17 of Set 7 | gizo
# Processing Record 18 of Set 7 | fairbanks
# Processing Record 19 of Set 7 | dalvik
# Processing Record 20 of Set 7 | la spezia
# Processing Record 21 of Set 7 | bayan
# Processing Record 22 of Set 7 | bubaque
# Processing Record 23 of Set 7 | mbanza-ngungu
# Processing Record 24 of Set 7 | rawannawi
# City not found. Skipping...
# Processing Record 25 of Set 7 | kopavogur
# Processing Record 26 of Set 7 | rondonopolis
# Processing Record 27 of Set 7 | svetlaya
# Processing Record 28 of Set 7 | sitka
# Processing Record 29 of Set 7 | aliwal north
# Processing Record 30 of Set 7 | tiarei
# Processing Record 31 of Set 7 | cururupu
# Processing Record 32 of Set 7 | vrangel
# Processing Record 33 of Set 7 | along
# Processing Record 34 of Set 7 | codrington
# Processing Record 35 of Set 7 | hurghada
# Processing Record 36 of Set 7 | nemuro
# Processing Record 37 of Set 7 | eldoret
# Processing Record 38 of Set 7 | khatanga
# Processing Record 39 of Set 7 | shchelyayur
# City not found. Skipping...
# Processing Record 40 of Set 7 | norman wells
# Processing Record 41 of Set 7 | namatanai
# Processing Record 42 of Set 7 | yaan
# Processing Record 43 of Set 7 | ucluelet
# Processing Record 44 of Set 7 | embu-guacu
# Processing Record 45 of Set 7 | bambous virieux
# Processing Record 46 of Set 7 | brae
# Processing Record 47 of Set 7 | djambala
# Processing Record 48 of Set 7 | grindavik
# Processing Record 49 of Set 7 | komsomolskiy
# Processing Record 50 of Set 7 | maragogi
# Processing Record 1 of Set 8 | kuytun
# Processing Record 2 of Set 8 | mumford
# Processing Record 3 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 4 of Set 8 | luang prabang
# Processing Record 5 of Set 8 | knysna
# Processing Record 6 of Set 8 | garzon
# Processing Record 7 of Set 8 | ayagoz
# Processing Record 8 of Set 8 | cockburn town
# Processing Record 9 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 10 of Set 8 | pont-saint-esprit
# Processing Record 11 of Set 8 | vila franca do campo
# Processing Record 12 of Set 8 | gadarwara
# Processing Record 13 of Set 8 | alyangula
# Processing Record 14 of Set 8 | chokurdakh
# Processing Record 15 of Set 8 | talnakh
# Processing Record 16 of Set 8 | faanui
# Processing Record 17 of Set 8 | iracoubo
# Processing Record 18 of Set 8 | tagusao
# Processing Record 19 of Set 8 | makat
# Processing Record 20 of Set 8 | harper
# Processing Record 21 of Set 8 | yulara
# Processing Record 22 of Set 8 | huittinen
# Processing Record 23 of Set 8 | sergach
# Processing Record 24 of Set 8 | oppdal
# Processing Record 25 of Set 8 | shizunai
# Processing Record 26 of Set 8 | havoysund
# Processing Record 27 of Set 8 | ondangwa
# Processing Record 28 of Set 8 | padang
# Processing Record 29 of Set 8 | lorengau
# Processing Record 30 of Set 8 | pascagoula
# Processing Record 31 of Set 8 | coolum beach
# Processing Record 32 of Set 8 | eureka
# Processing Record 33 of Set 8 | coquimbo
# Processing Record 34 of Set 8 | gigante
# Processing Record 35 of Set 8 | novoyegoryevskoye
# City not found. Skipping...
# Processing Record 36 of Set 8 | inongo
# Processing Record 37 of Set 8 | nouakchott
# Processing Record 38 of Set 8 | san quintin
# Processing Record 39 of Set 8 | pokaran
# Processing Record 40 of Set 8 | narsaq
# Processing Record 41 of Set 8 | evensk
# Processing Record 42 of Set 8 | canalete
# Processing Record 43 of Set 8 | magalia
# Processing Record 44 of Set 8 | pisco
# Processing Record 45 of Set 8 | poum
# Processing Record 46 of Set 8 | siparia
# Processing Record 47 of Set 8 | manaus
# Processing Record 48 of Set 8 | bur gabo
# City not found. Skipping...
# Processing Record 49 of Set 8 | kassala
# Processing Record 50 of Set 8 | karacabey
# Processing Record 1 of Set 9 | boa vista
# Processing Record 2 of Set 9 | ketchikan
# Processing Record 3 of Set 9 | zamania
# Processing Record 4 of Set 9 | porto santo
# Processing Record 5 of Set 9 | najran
# Processing Record 6 of Set 9 | pedro ii
# Processing Record 7 of Set 9 | trapani
# Processing Record 8 of Set 9 | burnie
# Processing Record 9 of Set 9 | temaraia
# City not found. Skipping...
# Processing Record 10 of Set 9 | porirua
# Processing Record 11 of Set 9 | haileybury
# Processing Record 12 of Set 9 | kulhudhuffushi
# Processing Record 13 of Set 9 | mahon
# Processing Record 14 of Set 9 | ola
# Processing Record 15 of Set 9 | sucevita
# Processing Record 16 of Set 9 | betanzos
# Processing Record 17 of Set 9 | ancud
# Processing Record 18 of Set 9 | hami
# Processing Record 19 of Set 9 | makakilo city
# Processing Record 20 of Set 9 | nizhneangarsk
# Processing Record 21 of Set 9 | mont-de-marsan
# Processing Record 22 of Set 9 | kisanga
# Processing Record 23 of Set 9 | ragandang
# Processing Record 24 of Set 9 | kidderminster
# Processing Record 25 of Set 9 | teul
# City not found. Skipping...
# Processing Record 26 of Set 9 | rawson
# Processing Record 27 of Set 9 | dryden
# Processing Record 28 of Set 9 | chepareria
# Processing Record 29 of Set 9 | san matias
# Processing Record 30 of Set 9 | chicama
# Processing Record 31 of Set 9 | semirom
# Processing Record 32 of Set 9 | tabuk
# Processing Record 33 of Set 9 | poshekhonye
# Processing Record 34 of Set 9 | balakhninskiy
# Processing Record 35 of Set 9 | phan thiet
# Processing Record 36 of Set 9 | lashio
# Processing Record 37 of Set 9 | hofn
# Processing Record 38 of Set 9 | tongling
# Processing Record 39 of Set 9 | lodja
# Processing Record 40 of Set 9 | tazovskiy
# Processing Record 41 of Set 9 | hobyo
# Processing Record 42 of Set 9 | ixtapa
# Processing Record 43 of Set 9 | viedma
# Processing Record 44 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 45 of Set 9 | sannicolaul mare
# City not found. Skipping...
# Processing Record 46 of Set 9 | nova serrana
# Processing Record 47 of Set 9 | khani
# Processing Record 48 of Set 9 | kankon
# Processing Record 49 of Set 9 | kasongo
# Processing Record 50 of Set 9 | daura
# Processing Record 1 of Set 10 | maloshuyka
# City not found. Skipping...
# Processing Record 2 of Set 10 | yar-sale
# Processing Record 3 of Set 10 | bandarbeyla
# Processing Record 4 of Set 10 | huarmey
# Processing Record 5 of Set 10 | dobric
# Processing Record 6 of Set 10 | wanxian
# Processing Record 7 of Set 10 | buenos aires
# Processing Record 8 of Set 10 | grand gaube
# Processing Record 9 of Set 10 | kytlym
# City not found. Skipping...
# Processing Record 10 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 11 of Set 10 | nouadhibou
# Processing Record 12 of Set 10 | tyrma
# Processing Record 13 of Set 10 | abha
# Processing Record 14 of Set 10 | abu samrah
# Processing Record 15 of Set 10 | tondano
# Processing Record 16 of Set 10 | rovaniemi
# Processing Record 17 of Set 10 | dawson creek
# Processing Record 18 of Set 10 | lamar
# Processing Record 19 of Set 10 | barawe
# City not found. Skipping...
# Processing Record 20 of Set 10 | durango
# Processing Record 21 of Set 10 | xingyi
# Processing Record 22 of Set 10 | astoria
# Processing Record 23 of Set 10 | jennings
# Processing Record 24 of Set 10 | ye
# City not found. Skipping...
# Processing Record 25 of Set 10 | la ronge
# Processing Record 26 of Set 10 | copiapo
# Processing Record 27 of Set 10 | three hills
# Processing Record 28 of Set 10 | south river
# Processing Record 29 of Set 10 | starodub
# Processing Record 30 of Set 10 | olavarria
# Processing Record 31 of Set 10 | merauke
# Processing Record 32 of Set 10 | kastamonu
# Processing Record 33 of Set 10 | vila do maio
# Processing Record 34 of Set 10 | tutoia
# Processing Record 35 of Set 10 | port-gentil
# Processing Record 36 of Set 10 | beringovskiy
# Processing Record 37 of Set 10 | baykit
# Processing Record 38 of Set 10 | lovozero
# Processing Record 39 of Set 10 | bowen
# Processing Record 40 of Set 10 | chaochou
# City not found. Skipping...
# Processing Record 41 of Set 10 | coahuayana
# Processing Record 42 of Set 10 | nokaneng
# Processing Record 43 of Set 10 | cabo san lucas
# Processing Record 44 of Set 10 | meadow lake
# Processing Record 45 of Set 10 | anadyr
# Processing Record 46 of Set 10 | pangoa
# Processing Record 47 of Set 10 | timra
# Processing Record 48 of Set 10 | vershino-darasunskiy
# Processing Record 49 of Set 10 | chapais
# Processing Record 50 of Set 10 | hosakote
# Processing Record 1 of Set 11 | nesbyen
# Processing Record 2 of Set 11 | labuhan
# Processing Record 3 of Set 11 | pitkyaranta
# Processing Record 4 of Set 11 | lapeer
# Processing Record 5 of Set 11 | tura
# Processing Record 6 of Set 11 | pacific grove
# Processing Record 7 of Set 11 | zhigalovo
# Processing Record 8 of Set 11 | bacabal
# Processing Record 9 of Set 11 | kant
# Processing Record 10 of Set 11 | muroto
# Processing Record 11 of Set 11 | kattivakkam
# Processing Record 12 of Set 11 | saint pete beach
# Processing Record 13 of Set 11 | kollumerland
# City not found. Skipping...
# Processing Record 14 of Set 11 | santa maria
# Processing Record 15 of Set 11 | dublin
# Processing Record 16 of Set 11 | xiamen
# Processing Record 17 of Set 11 | la rioja
# Processing Record 18 of Set 11 | kango
# Processing Record 19 of Set 11 | mayor pablo lagerenza
# Processing Record 20 of Set 11 | mount gambier
# Processing Record 21 of Set 11 | rocha
# Processing Record 22 of Set 11 | sapucai
# Processing Record 23 of Set 11 | puerto escondido
# Processing Record 24 of Set 11 | grants
# Processing Record 25 of Set 11 | srednekolymsk
# Processing Record 26 of Set 11 | beyneu
# Processing Record 27 of Set 11 | sebring
# Processing Record 28 of Set 11 | tessalit
# Processing Record 29 of Set 11 | sindor
# Processing Record 30 of Set 11 | port augusta
# Processing Record 31 of Set 11 | lata
# Processing Record 32 of Set 11 | pinyug
# Processing Record 33 of Set 11 | iqaluit
# Processing Record 34 of Set 11 | dwarka
# Processing Record 35 of Set 11 | kalabo
# Processing Record 36 of Set 11 | burica
# City not found. Skipping...
# Processing Record 37 of Set 11 | de aar
# Processing Record 38 of Set 11 | tual
# Processing Record 39 of Set 11 | henties bay
# Processing Record 40 of Set 11 | kodinsk
# Processing Record 41 of Set 11 | muzhi
# Processing Record 42 of Set 11 | nanortalik
# Processing Record 43 of Set 11 | tupaciguara
# Processing Record 44 of Set 11 | bandar-e lengeh
# Processing Record 45 of Set 11 | puerto carreno
# Processing Record 46 of Set 11 | san patricio
# Processing Record 47 of Set 11 | kismayo
# Processing Record 48 of Set 11 | san gavino monreale
# Processing Record 49 of Set 11 | banmo
# City not found. Skipping...
# Processing Record 50 of Set 11 | salalah
# Processing Record 1 of Set 12 | methoni
# Processing Record 2 of Set 12 | hualmay
# Processing Record 3 of Set 12 | agadir
# Processing Record 4 of Set 12 | general roca
# Processing Record 5 of Set 12 | varnavino
# Processing Record 6 of Set 12 | jacareacanga
# Processing Record 7 of Set 12 | hailey
# Processing Record 8 of Set 12 | le pradet
# Processing Record 9 of Set 12 | aykhal
# Processing Record 10 of Set 12 | karpogory
# Processing Record 11 of Set 12 | burkhala
# City not found. Skipping...
# Processing Record 12 of Set 12 | carauari
# Processing Record 13 of Set 12 | carutapera
# Processing Record 14 of Set 12 | college
# Processing Record 15 of Set 12 | artyk
# City not found. Skipping...
# Processing Record 16 of Set 12 | ypsonas
# Processing Record 17 of Set 12 | hovd
# Processing Record 18 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 19 of Set 12 | port macquarie
# Processing Record 20 of Set 12 | manggar
# Processing Record 21 of Set 12 | marsa matruh
# Processing Record 22 of Set 12 | barabash
# Processing Record 23 of Set 12 | rize
# Processing Record 24 of Set 12 | joensuu
# Processing Record 25 of Set 12 | ambovombe
# Processing Record 26 of Set 12 | nurota
# Processing Record 27 of Set 12 | malindi
# Processing Record 28 of Set 12 | westport
# Processing Record 29 of Set 12 | waitara
# Processing Record 30 of Set 12 | saint anthony
# Processing Record 31 of Set 12 | nabire
# Processing Record 32 of Set 12 | sur
# Processing Record 33 of Set 12 | sembakung
# Processing Record 34 of Set 12 | balakhta
# Processing Record 35 of Set 12 | khor
# Processing Record 36 of Set 12 | largs
# Processing Record 37 of Set 12 | kabwe
# Processing Record 38 of Set 12 | virginia beach
# Processing Record 39 of Set 12 | pemberton
# Processing Record 40 of Set 12 | parede
# Processing Record 41 of Set 12 | miri
# Processing Record 42 of Set 12 | moroni
# Processing Record 43 of Set 12 | manaure
# Processing Record 44 of Set 12 | naenwa
# City not found. Skipping...
# Processing Record 45 of Set 12 | sao jose da coroa grande
# Processing Record 46 of Set 12 | ust-nera
# Processing Record 47 of Set 12 | spassk-ryazanskiy
# Processing Record 48 of Set 12 | telma
# Processing Record 49 of Set 12 | port blair
# Processing Record 50 of Set 12 | kailua
# Processing Record 1 of Set 13 | behshahr
# Processing Record 2 of Set 13 | dicabisagan
# Processing Record 3 of Set 13 | ambon
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %%
city_data
# Out:
# [{'City': 'Beloha',
#   'Country': 'MG',
#   'Lat': -25.1667,
#   'Lng': 45.05,
#   'Max Temp': 59,
#   'Humidity': 77,
#   'Cloudiness': 1,
#   'Wind Speed': 10.74,
#   'Current Description': 'clear sky'},
#  {'City': 'Severo-Kurilsk',
#   'Country': 'RU',
#   'Lat': 50.6789,
#   'Lng': 156.125,
#   'Max Temp': 59.34,
#   'Humidity': 88,
#   'Cloudiness': 74,
#   'Wind Speed': 3.49,
#   'Current Description': 'broken clouds'},
#  {'City': 'Esperance',
#   'Country': 'AU',
#   'Lat': -33.8667,
#   'Lng': 121.9,
#   'Max Temp': 58.84,
#   'Humidity': 72,
#   'Cloudiness': 3,
#   'Wind Speed': 22.48,
#   'Current Description': 'clear sky'},
#  {'City': 'Bijie',
#   'Country': 'CN',
#   'Lat': 27.3125,
#   'Lng': 105.2942,
#   'Max Temp': 72.84,
#   'Humidity': 75,
#   'Cloudiness': 7,
#   'Wind Speed': 1.25,
#   'Current Description': 'clear sky'},
#  {'City': 'Castro',
#   'Country': 'BR',
#   'Lat': -24.7911,
#   'Lng': -50.0119,
#   'Max Temp': 54.99,
#   'Humidity': 61,
#   'Cloudiness': 5,
#   'Wind Speed': 3.51,
#   'Current Description': 'clear sky'},
#  {'City': 'Sorland',
#   'Country': 'NO',
#   'Lat': 67.667,
#   'Lng': 12.6934,
#   'Max Temp': 54.14,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 4.59,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Nikolskoye',
#   'Country': 'RU',
#   'Lat': 59.7035,
#   'Lng': 30.7861,
#   'Max Temp': 63.81,
#   'Humidity': 62,
#   'Cloudiness': 89,
#   'Wind Speed': 4.34,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Husavik',
#   'Country': 'IS',
#   'Lat': 66.0449,
#   'Lng': -17.3389,
#   'Max Temp': 51.98,
#   'Humidity': 65,
#   'Cloudiness': 0,
#   'Wind Speed': 15.14,
#   'Current Description': 'clear sky'},
#  {'City': 'Yerbogachen',
#   'Country': 'RU',
#   'Lat': 61.2767,
#   'Lng': 108.0108,
#   'Max Temp': 79.11,
#   'Humidity': 41,
#   'Cloudiness': 52,
#   'Wind Speed': 2.93,
#   'Current Description': 'broken clouds'},
#  {'City': 'Hermanus',
#   'Country': 'ZA',
#   'Lat': -34.4187,
#   'Lng': 19.2345,
#   'Max Temp': 50.81,
#   'Humidity': 51,
#   'Cloudiness': 100,
#   'Wind Speed': 9.51,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Akyab',
#   'Country': 'MM',
#   'Lat': 20.15,
#   'Lng': 92.9,
#   'Max Temp': 79.36,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 22.66,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Punta Arenas',
#   'Country': 'CL',
#   'Lat': -53.15,
#   'Lng': -70.9167,
#   'Max Temp': 33.91,
#   'Humidity': 93,
#   'Cloudiness': 0,
#   'Wind Speed': 12.66,
#   'Current Description': 'clear sky'},
#  {'City': 'Vila Velha',
#   'Country': 'BR',
#   'Lat': -20.3297,
#   'Lng': -40.2925,
#   'Max Temp': 64.35,
#   'Humidity': 94,
#   'Cloudiness': 0,
#   'Wind Speed': 0,
#   'Current Description': 'clear sky'},
#  {'City': 'Pochutla',
#   'Country': 'MX',
#   'Lat': 15.7432,
#   'Lng': -96.4661,
#   'Max Temp': 78.82,
#   'Humidity': 92,
#   'Cloudiness': 99,
#   'Wind Speed': 3.62,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Saint George',
#   'Country': 'US',
#   'Lat': 37.1041,
#   'Lng': -113.5841,
#   'Max Temp': 82.35,
#   'Humidity': 60,
#   'Cloudiness': 1,
#   'Wind Speed': 1.99,
#   'Current Description': 'clear sky'},
#  {'City': 'Jamestown',
#   'Country': 'US',
#   'Lat': 42.097,
#   'Lng': -79.2353,
#   'Max Temp': 71.24,
#   'Humidity': 83,
#   'Cloudiness': 1,
#   'Wind Speed': 3.29,
#   'Current Description': 'clear sky'},
#  {'City': 'Piopio',
#   'Country': 'NZ',
#   'Lat': -38.4667,
#   'Lng': 175.0167,
#   'Max Temp': 57.96,
#   'Humidity': 97,
#   'Cloudiness': 77,
#   'Wind Speed': 5.39,
#   'Current Description': 'broken clouds'},
#  {'City': 'Lapua',
#   'Country': 'FI',
#   'Lat': 62.9693,
#   'Lng': 23.0088,
#   'Max Temp': 55.35,
#   'Humidity': 80,
#   'Cloudiness': 86,
#   'Wind Speed': 3.58,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Saskylakh',
#   'Country': 'RU',
#   'Lat': 71.9167,
#   'Lng': 114.0833,
#   'Max Temp': 59.65,
#   'Humidity': 56,
#   'Cloudiness': 89,
#   'Wind Speed': 16.37,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hobart',
#   'Country': 'AU',
#   'Lat': -42.8794,
#   'Lng': 147.3294,
#   'Max Temp': 55.26,
#   'Humidity': 64,
#   'Cloudiness': 75,
#   'Wind Speed': 3,
#   'Current Description': 'broken clouds'},
#  {'City': 'Albany',
#   'Country': 'US',
#   'Lat': 42.6001,
#   'Lng': -73.9662,
#   'Max Temp': 72.39,
#   'Humidity': 94,
#   'Cloudiness': 0,
#   'Wind Speed': 4.09,
#   'Current Description': 'clear sky'},
#  {'City': 'Puerto Ayora',
#   'Country': 'EC',
#   'Lat': -0.7393,
#   'Lng': -90.3518,
#   'Max Temp': 71.55,
#   'Humidity': 89,
#   'Cloudiness': 3,
#   'Wind Speed': 5.99,
#   'Current Description': 'clear sky'},
#  {'City': 'Mataura',
#   'Country': 'NZ',
#   'Lat': -46.1927,
#   'Lng': 168.8643,
#   'Max Temp': 49.48,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 1.57,
#   'Current Description': 'light rain'},
#  {'City': 'Rikitea',
#   'Country': 'PF',
#   'Lat': -23.1203,
#   'Lng': -134.9692,
#   'Max Temp': 71.51,
#   'Humidity': 73,
#   'Cloudiness': 22,
#   'Wind Speed': 6.02,
#   'Current Description': 'few clouds'},
#  {'City': 'Tiksi',
#   'Country': 'RU',
#   'Lat': 71.6872,
#   'Lng': 128.8694,
#   'Max Temp': 56.1,
#   'Humidity': 79,
#   'Cloudiness': 83,
#   'Wind Speed': 8.88,
#   'Current Description': 'broken clouds'},
#  {'City': 'Diu',
#   'Country': 'IN',
#   'Lat': 20.7141,
#   'Lng': 70.9822,
#   'Max Temp': 78.42,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 20.6,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Pacifica',
#   'Country': 'US',
#   'Lat': 37.6138,
#   'Lng': -122.4869,
#   'Max Temp': 84.56,
#   'Humidity': 80,
#   'Cloudiness': 75,
#   'Wind Speed': 4,
#   'Current Description': 'broken clouds'},
#  {'City': 'Clyde River',
#   'Country': 'CA',
#   'Lat': 70.4692,
#   'Lng': -68.5914,
#   'Max Temp': 34.03,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 4.61,
#   'Current Description': 'light rain'},
#  {'City': 'Busselton',
#   'Country': 'AU',
#   'Lat': -33.65,
#   'Lng': 115.3333,
#   'Max Temp': 65.05,
#   'Humidity': 71,
#   'Cloudiness': 1,
#   'Wind Speed': 25.17,
#   'Current Description': 'clear sky'},
#  {'City': 'Nalut',
#   'Country': 'LY',
#   'Lat': 30.3333,
#   'Lng': 10.85,
#   'Max Temp': 78.35,
#   'Humidity': 25,
#   'Cloudiness': 0,
#   'Wind Speed': 11.92,
#   'Current Description': 'clear sky'},
#  {'City': 'Aksu',
#   'Country': 'CN',
#   'Lat': 41.1231,
#   'Lng': 80.2644,
#   'Max Temp': 89.6,
#   'Humidity': 17,
#   'Cloudiness': 0,
#   'Wind Speed': 4.21,
#   'Current Description': 'clear sky'},
#  {'City': 'Otjimbingwe',
#   'Country': 'NA',
#   'Lat': -22.35,
#   'Lng': 16.1333,
#   'Max Temp': 55.35,
#   'Humidity': 50,
#   'Cloudiness': 24,
#   'Wind Speed': 8.03,
#   'Current Description': 'few clouds'},
#  {'City': 'Bredasdorp',
#   'Country': 'ZA',
#   'Lat': -34.5322,
#   'Lng': 20.0403,
#   'Max Temp': 50.29,
#   'Humidity': 42,
#   'Cloudiness': 100,
#   'Wind Speed': 6.55,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Saint-Philippe',
#   'Country': 'RE',
#   'Lat': -21.3585,
#   'Lng': 55.7679,
#   'Max Temp': 65.75,
#   'Humidity': 70,
#   'Cloudiness': 58,
#   'Wind Speed': 11.5,
#   'Current Description': 'broken clouds'},
#  {'City': 'Saint-Leu',
#   'Country': 'RE',
#   'Lat': -21.15,
#   'Lng': 55.2833,
#   'Max Temp': 65.23,
#   'Humidity': 70,
#   'Cloudiness': 19,
#   'Wind Speed': 6.82,
#   'Current Description': 'few clouds'},
#  {'City': 'Port Alfred',
#   'Country': 'ZA',
#   'Lat': -33.5906,
#   'Lng': 26.891,
#   'Max Temp': 59.74,
#   'Humidity': 31,
#   'Cloudiness': 43,
#   'Wind Speed': 11.9,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Pevek',
#   'Country': 'RU',
#   'Lat': 69.7008,
#   'Lng': 170.3133,
#   'Max Temp': 35.94,
#   'Humidity': 88,
#   'Cloudiness': 79,
#   'Wind Speed': 10.11,
#   'Current Description': 'broken clouds'},
#  {'City': 'Bethel',
#   'Country': 'US',
#   'Lat': 41.3712,
#   'Lng': -73.414,
#   'Max Temp': 74.68,
#   'Humidity': 90,
#   'Cloudiness': 0,
#   'Wind Speed': 2.46,
#   'Current Description': 'clear sky'},
#  {'City': 'Bluff',
#   'Country': 'NZ',
#   'Lat': -46.6,
#   'Lng': 168.3333,
#   'Max Temp': 49.8,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 1.52,
#   'Current Description': 'moderate rain'},
#  {'City': 'Avarua',
#   'Country': 'CK',
#   'Lat': -21.2078,
#   'Lng': -159.775,
#   'Max Temp': 78.85,
#   'Humidity': 73,
#   'Cloudiness': 20,
#   'Wind Speed': 10.36,
#   'Current Description': 'few clouds'},
#  {'City': 'Jiexiu',
#   'Country': 'CN',
#   'Lat': 37.0244,
#   'Lng': 111.9125,
#   'Max Temp': 82.17,
#   'Humidity': 59,
#   'Cloudiness': 100,
#   'Wind Speed': 4.68,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tasiilaq',
#   'Country': 'GL',
#   'Lat': 65.6145,
#   'Lng': -37.6368,
#   'Max Temp': 41.16,
#   'Humidity': 84,
#   'Cloudiness': 27,
#   'Wind Speed': 4.5,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Sao Felix Do Xingu',
#   'Country': 'BR',
#   'Lat': -6.6447,
#   'Lng': -51.995,
#   'Max Temp': 72.32,
#   'Humidity': 50,
#   'Cloudiness': 5,
#   'Wind Speed': 1.88,
#   'Current Description': 'clear sky'},
#  {'City': 'Haines Junction',
#   'Country': 'CA',
#   'Lat': 60.7522,
#   'Lng': -137.5108,
#   'Max Temp': 61.16,
#   'Humidity': 48,
#   'Cloudiness': 100,
#   'Wind Speed': 4.52,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kilindoni',
#   'Country': 'TZ',
#   'Lat': -7.9139,
#   'Lng': 39.6668,
#   'Max Temp': 73.54,
#   'Humidity': 74,
#   'Cloudiness': 85,
#   'Wind Speed': 20.4,
#   'Current Description': 'light rain'},
#  {'City': 'Atar',
#   'Country': 'MR',
#   'Lat': 20.5169,
#   'Lng': -13.0499,
#   'Max Temp': 86,
#   'Humidity': 33,
#   'Cloudiness': 99,
#   'Wind Speed': 5.28,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Brainerd',
#   'Country': 'US',
#   'Lat': 46.358,
#   'Lng': -94.2008,
#   'Max Temp': 77.29,
#   'Humidity': 30,
#   'Cloudiness': 0,
#   'Wind Speed': 2.37,
#   'Current Description': 'clear sky'},
#  {'City': 'Nizhniy Baskunchak',
#   'Country': 'RU',
#   'Lat': 48.2198,
#   'Lng': 46.8311,
#   'Max Temp': 75.52,
#   'Humidity': 37,
#   'Cloudiness': 92,
#   'Wind Speed': 11.32,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Atuona',
#   'Country': 'PF',
#   'Lat': -9.8,
#   'Lng': -139.0333,
#   'Max Temp': 78.28,
#   'Humidity': 71,
#   'Cloudiness': 6,
#   'Wind Speed': 24.85,
#   'Current Description': 'clear sky'},
#  {'City': 'Moron De La Frontera',
#   'Country': 'ES',
#   'Lat': 37.1208,
#   'Lng': -5.454,
#   'Max Temp': 74.61,
#   'Humidity': 73,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Current Description': 'clear sky'},
#  {'City': 'Butaritari',
#   'Country': 'KI',
#   'Lat': 3.0707,
#   'Lng': 172.7902,
#   'Max Temp': 78.96,
#   'Humidity': 87,
#   'Cloudiness': 99,
#   'Wind Speed': 15.84,
#   'Current Description': 'moderate rain'},
#  {'City': 'Quepos',
#   'Country': 'CR',
#   'Lat': 9.4236,
#   'Lng': -84.1652,
#   'Max Temp': 82.06,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 7.61,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Longyearbyen',
#   'Country': 'SJ',
#   'Lat': 78.2186,
#   'Lng': 15.6401,
#   'Max Temp': 44.44,
#   'Humidity': 81,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Current Description': 'broken clouds'},
#  {'City': 'Mandalgovi',
#   'Country': 'MN',
#   'Lat': 45.7625,
#   'Lng': 106.2708,
#   'Max Temp': 64.17,
#   'Humidity': 62,
#   'Cloudiness': 100,
#   'Wind Speed': 9.98,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Cherskiy',
#   'Country': 'RU',
#   'Lat': 68.75,
#   'Lng': 161.3,
#   'Max Temp': 54.93,
#   'Humidity': 46,
#   'Cloudiness': 0,
#   'Wind Speed': 13.35,
#   'Current Description': 'clear sky'},
#  {'City': 'Souillac',
#   'Country': 'MU',
#   'Lat': -20.5167,
#   'Lng': 57.5167,
#   'Max Temp': 68.11,
#   'Humidity': 65,
#   'Cloudiness': 1,
#   'Wind Speed': 10.07,
#   'Current Description': 'clear sky'},
#  {'City': 'Tezu',
#   'Country': 'IN',
#   'Lat': 27.9167,
#   'Lng': 96.1667,
#   'Max Temp': 80.13,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 0.4,
#   'Current Description': 'light rain'},
#  {'City': 'Sola',
#   'Country': 'VU',
#   'Lat': -13.8833,
#   'Lng': 167.55,
#   'Max Temp': 80.33,
#   'Humidity': 78,
#   'Cloudiness': 18,
#   'Wind Speed': 10.76,
#   'Current Description': 'few clouds'},
#  {'City': 'Ushuaia',
#   'Country': 'AR',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 33.46,
#   'Humidity': 80,
#   'Cloudiness': 20,
#   'Wind Speed': 4.61,
#   'Current Description': 'few clouds'},
#  {'City': 'Baruun-Urt',
#   'Country': 'MN',
#   'Lat': 46.6806,
#   'Lng': 113.2792,
#   'Max Temp': 66.25,
#   'Humidity': 56,
#   'Cloudiness': 100,
#   'Wind Speed': 13.87,
#   'Current Description': 'light rain'},
#  {'City': 'Yellowknife',
#   'Country': 'CA',
#   'Lat': 62.456,
#   'Lng': -114.3525,
#   'Max Temp': 60.3,
#   'Humidity': 49,
#   'Cloudiness': 51,
#   'Wind Speed': 1.01,
#   'Current Description': 'broken clouds'},
#  {'City': 'Kavieng',
#   'Country': 'PG',
#   'Lat': -2.5744,
#   'Lng': 150.7967,
#   'Max Temp': 83.79,
#   'Humidity': 68,
#   'Cloudiness': 30,
#   'Wind Speed': 4.25,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Te Anau',
#   'Country': 'NZ',
#   'Lat': -45.4167,
#   'Lng': 167.7167,
#   'Max Temp': 46.8,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 1.59,
#   'Current Description': 'light rain'},
#  {'City': 'Luau',
#   'Country': 'AO',
#   'Lat': -10.7073,
#   'Lng': 22.2247,
#   'Max Temp': 58.66,
#   'Humidity': 43,
#   'Cloudiness': 18,
#   'Wind Speed': 7.87,
#   'Current Description': 'few clouds'},
#  {'City': 'Sao Filipe',
#   'Country': 'CV',
#   'Lat': 14.8961,
#   'Lng': -24.4956,
#   'Max Temp': 73.71,
#   'Humidity': 77,
#   'Cloudiness': 74,
#   'Wind Speed': 6.04,
#   'Current Description': 'broken clouds'},
#  {'City': 'Erenhot',
#   'Country': 'CN',
#   'Lat': 43.6475,
#   'Lng': 111.9767,
#   'Max Temp': 66.87,
#   'Humidity': 61,
#   'Cloudiness': 87,
#   'Wind Speed': 16.84,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mitsamiouli',
#   'Country': 'KM',
#   'Lat': -11.3847,
#   'Lng': 43.2844,
#   'Max Temp': 76.1,
#   'Humidity': 69,
#   'Cloudiness': 74,
#   'Wind Speed': 13.31,
#   'Current Description': 'light rain'},
#  {'City': 'Oudtshoorn',
#   'Country': 'ZA',
#   'Lat': -33.5907,
#   'Lng': 22.2014,
#   'Max Temp': 62.96,
#   'Humidity': 33,
#   'Cloudiness': 66,
#   'Wind Speed': 9.55,
#   'Current Description': 'broken clouds'},
#  {'City': 'Kapaa',
#   'Country': 'US',
#   'Lat': 22.0752,
#   'Lng': -159.319,
#   'Max Temp': 87.78,
#   'Humidity': 79,
#   'Cloudiness': 61,
#   'Wind Speed': 3,
#   'Current Description': 'light rain'},
#  {'City': 'Hilo',
#   'Country': 'US',
#   'Lat': 19.7297,
#   'Lng': -155.09,
#   'Max Temp': 75.61,
#   'Humidity': 94,
#   'Cloudiness': 90,
#   'Wind Speed': 8.05,
#   'Current Description': 'moderate rain'},
#  {'City': 'Ahuimanu',
#   'Country': 'US',
#   'Lat': 21.4447,
#   'Lng': -157.8378,
#   'Max Temp': 87.51,
#   'Humidity': 67,
#   'Cloudiness': 75,
#   'Wind Speed': 11.5,
#   'Current Description': 'broken clouds'},
#  {'City': 'Vaini',
#   'Country': 'TO',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 80.76,
#   'Humidity': 83,
#   'Cloudiness': 20,
#   'Wind Speed': 9.22,
#   'Current Description': 'few clouds'},
#  {'City': 'Walvis Bay',
#   'Country': 'NA',
#   'Lat': -22.9575,
#   'Lng': 14.5053,
#   'Max Temp': 71.01,
#   'Humidity': 33,
#   'Cloudiness': 91,
#   'Wind Speed': 12.57,
#   'Current Description': 'overcast clouds'},
#  {'City': 'San Cristobal',
#   'Country': 'VE',
#   'Lat': 7.7669,
#   'Lng': -72.225,
#   'Max Temp': 69.98,
#   'Humidity': 99,
#   'Cloudiness': 97,
#   'Wind Speed': 2.66,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bilma',
#   'Country': 'NE',
#   'Lat': 18.6853,
#   'Lng': 12.9164,
#   'Max Temp': 88.59,
#   'Humidity': 42,
#   'Cloudiness': 99,
#   'Wind Speed': 12.44,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Glen Allen',
#   'Country': 'US',
#   'Lat': 37.666,
#   'Lng': -77.5064,
#   'Max Temp': 83.3,
#   'Humidity': 81,
#   'Cloudiness': 56,
#   'Wind Speed': 1.01,
#   'Current Description': 'broken clouds'},
#  {'City': 'Andenes',
#   'Country': 'NO',
#   'Lat': 69.3143,
#   'Lng': 16.1194,
#   'Max Temp': 52.47,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 4.61,
#   'Current Description': 'mist'},
#  {'City': 'Hithadhoo',
#   'Country': 'MV',
#   'Lat': -0.6,
#   'Lng': 73.0833,
#   'Max Temp': 80.98,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 5.84,
#   'Current Description': 'moderate rain'},
#  {'City': 'Kruisfontein',
#   'Country': 'ZA',
#   'Lat': -34.0033,
#   'Lng': 24.7314,
#   'Max Temp': 51.89,
#   'Humidity': 34,
#   'Cloudiness': 100,
#   'Wind Speed': 11.59,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Golden',
#   'Country': 'US',
#   'Lat': 39.7555,
#   'Lng': -105.2211,
#   'Max Temp': 80.06,
#   'Humidity': 69,
#   'Cloudiness': 75,
#   'Wind Speed': 4,
#   'Current Description': 'thunderstorm'},
#  {'City': 'Hamilton',
#   'Country': 'US',
#   'Lat': 39.1834,
#   'Lng': -84.5333,
#   'Max Temp': 80.01,
#   'Humidity': 82,
#   'Cloudiness': 40,
#   'Wind Speed': 0,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Boulsa',
#   'Country': 'BF',
#   'Lat': 12.6675,
#   'Lng': -0.5758,
#   'Max Temp': 77.86,
#   'Humidity': 73,
#   'Cloudiness': 92,
#   'Wind Speed': 8.48,
#   'Current Description': 'light rain'},
#  {'City': 'Airai',
#   'Country': 'TL',
#   'Lat': -8.9266,
#   'Lng': 125.4092,
#   'Max Temp': 74.84,
#   'Humidity': 26,
#   'Cloudiness': 83,
#   'Wind Speed': 3.38,
#   'Current Description': 'broken clouds'},
#  {'City': 'Sakaiminato',
#   'Country': 'JP',
#   'Lat': 35.55,
#   'Lng': 133.2333,
#   'Max Temp': 89.53,
#   'Humidity': 57,
#   'Cloudiness': 2,
#   'Wind Speed': 5.88,
#   'Current Description': 'clear sky'},
#  {'City': 'Olga',
#   'Country': 'RU',
#   'Lat': 43.7444,
#   'Lng': 135.2892,
#   'Max Temp': 81.88,
#   'Humidity': 69,
#   'Cloudiness': 14,
#   'Wind Speed': 6.64,
#   'Current Description': 'few clouds'},
#  {'City': 'Coruripe',
#   'Country': 'BR',
#   'Lat': -10.1256,
#   'Lng': -36.1756,
#   'Max Temp': 72.55,
#   'Humidity': 88,
#   'Cloudiness': 62,
#   'Wind Speed': 10.89,
#   'Current Description': 'broken clouds'},
#  {'City': 'Benguela',
#   'Country': 'AO',
#   'Lat': -12.5763,
#   'Lng': 13.4055,
#   'Max Temp': 68.68,
#   'Humidity': 78,
#   'Cloudiness': 4,
#   'Wind Speed': 3.47,
#   'Current Description': 'clear sky'},
#  {'City': 'Katherine',
#   'Country': 'AU',
#   'Lat': -14.4667,
#   'Lng': 132.2667,
#   'Max Temp': 82.72,
#   'Humidity': 44,
#   'Cloudiness': 100,
#   'Wind Speed': 12.66,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Port Hardy',
#   'Country': 'CA',
#   'Lat': 50.6996,
#   'Lng': -127.4199,
#   'Max Temp': 62.37,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 9.08,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ilulissat',
#   'Country': 'GL',
#   'Lat': 69.2167,
#   'Lng': -51.1,
#   'Max Temp': 50.02,
#   'Humidity': 43,
#   'Cloudiness': 100,
#   'Wind Speed': 11.5,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Fortuna',
#   'Country': 'US',
#   'Lat': 40.5982,
#   'Lng': -124.1573,
#   'Max Temp': 55.98,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 11.5,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Maloy',
#   'Country': 'NO',
#   'Lat': 61.9353,
#   'Lng': 5.1136,
#   'Max Temp': 64.13,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 5.75,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Victoria',
#   'Country': 'HK',
#   'Lat': 22.2855,
#   'Lng': 114.1577,
#   'Max Temp': 91.33,
#   'Humidity': 81,
#   'Cloudiness': 47,
#   'Wind Speed': 1.01,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Klaksvik',
#   'Country': 'FO',
#   'Lat': 62.2266,
#   'Lng': -6.589,
#   'Max Temp': 50.92,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 8.9,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Thompson',
#   'Country': 'CA',
#   'Lat': 55.7435,
#   'Lng': -97.8558,
#   'Max Temp': 60.69,
#   'Humidity': 32,
#   'Cloudiness': 5,
#   'Wind Speed': 6.96,
#   'Current Description': 'clear sky'},
#  {'City': 'Kloulklubed',
#   'Country': 'PW',
#   'Lat': 7.0419,
#   'Lng': 134.2556,
#   'Max Temp': 81.1,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 17.31,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Launceston',
#   'Country': 'AU',
#   'Lat': -41.45,
#   'Lng': 147.1667,
#   'Max Temp': 52.81,
#   'Humidity': 94,
#   'Cloudiness': 90,
#   'Wind Speed': 3,
#   'Current Description': 'light rain'},
#  {'City': 'Arraial Do Cabo',
#   'Country': 'BR',
#   'Lat': -22.9661,
#   'Lng': -42.0278,
#   'Max Temp': 69.8,
#   'Humidity': 77,
#   'Cloudiness': 0,
#   'Wind Speed': 25.99,
#   'Current Description': 'clear sky'},
#  {'City': 'Avera',
#   'Country': 'US',
#   'Lat': 33.194,
#   'Lng': -82.5271,
#   'Max Temp': 82.71,
#   'Humidity': 71,
#   'Cloudiness': 71,
#   'Wind Speed': 5.28,
#   'Current Description': 'broken clouds'},
#  {'City': 'East London',
#   'Country': 'ZA',
#   'Lat': -33.0153,
#   'Lng': 27.9116,
#   'Max Temp': 58.69,
#   'Humidity': 26,
#   'Cloudiness': 32,
#   'Wind Speed': 6.51,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Herran',
#   'Country': 'CO',
#   'Lat': 7.5061,
#   'Lng': -72.4833,
#   'Max Temp': 59.2,
#   'Humidity': 98,
#   'Cloudiness': 87,
#   'Wind Speed': 4.05,
#   'Current Description': 'overcast clouds'},
#  {'City': 'New Norfolk',
#   'Country': 'AU',
#   'Lat': -42.7826,
#   'Lng': 147.0587,
#   'Max Temp': 54.9,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 1.01,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bengkulu',
#   'Country': 'ID',
#   'Lat': -3.8004,
#   'Lng': 102.2655,
#   'Max Temp': 81.16,
#   'Humidity': 63,
#   'Cloudiness': 0,
#   'Wind Speed': 2.51,
#   'Current Description': 'clear sky'},
#  {'City': 'Camacari',
#   'Country': 'BR',
#   'Lat': -12.6975,
#   'Lng': -38.3242,
#   'Max Temp': 68.65,
#   'Humidity': 93,
#   'Cloudiness': 29,
#   'Wind Speed': 5.17,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Ziniare',
#   'Country': 'BF',
#   'Lat': 12.5822,
#   'Lng': -1.2983,
#   'Max Temp': 76.71,
#   'Humidity': 77,
#   'Cloudiness': 73,
#   'Wind Speed': 7.67,
#   'Current Description': 'light rain'},
#  {'City': 'Keti Bandar',
#   'Country': 'PK',
#   'Lat': 24.1447,
#   'Lng': 67.4497,
#   'Max Temp': 82.96,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 23.71,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kautokeino',
#   'Country': 'NO',
#   'Lat': 69.0125,
#   'Lng': 23.0412,
#   'Max Temp': 51.04,
#   'Humidity': 90,
#   'Cloudiness': 97,
#   'Wind Speed': 2.44,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Dauphin',
#   'Country': 'CA',
#   'Lat': 51.1494,
#   'Lng': -100.0502,
#   'Max Temp': 73.98,
#   'Humidity': 38,
#   'Cloudiness': 72,
#   'Wind Speed': 9.26,
#   'Current Description': 'broken clouds'},
#  {'City': 'Zhangjiakou',
#   'Country': 'CN',
#   'Lat': 40.81,
#   'Lng': 114.8794,
#   'Max Temp': 75.74,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 8.14,
#   'Current Description': 'light rain'},
#  {'City': 'Marsh Harbour',
#   'Country': 'BS',
#   'Lat': 26.5412,
#   'Lng': -77.0636,
#   'Max Temp': 82.45,
#   'Humidity': 78,
#   'Cloudiness': 91,
#   'Wind Speed': 14.07,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Margate',
#   'Country': 'GB',
#   'Lat': 51.3813,
#   'Lng': 1.3862,
#   'Max Temp': 64.31,
#   'Humidity': 94,
#   'Cloudiness': 92,
#   'Wind Speed': 1.01,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kudahuvadhoo',
#   'Country': 'MV',
#   'Lat': 2.6708,
#   'Lng': 72.8944,
#   'Max Temp': 82.58,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 6.4,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tigil',
#   'Country': 'RU',
#   'Lat': 57.8,
#   'Lng': 158.6667,
#   'Max Temp': 72.16,
#   'Humidity': 64,
#   'Cloudiness': 76,
#   'Wind Speed': 15.61,
#   'Current Description': 'broken clouds'},
#  {'City': 'Lilongwe',
#   'Country': 'MW',
#   'Lat': -13.9669,
#   'Lng': 33.7873,
#   'Max Temp': 51.44,
#   'Humidity': 72,
#   'Cloudiness': 18,
#   'Wind Speed': 8.39,
#   'Current Description': 'few clouds'},
#  {'City': 'Constitucion',
#   'Country': 'CL',
#   'Lat': -35.3333,
#   'Lng': -72.4167,
#   'Max Temp': 50.56,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 9.8,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Binzhou',
#   'Country': 'CN',
#   'Lat': 37.3667,
#   'Lng': 118.0167,
#   'Max Temp': 92.26,
#   'Humidity': 53,
#   'Cloudiness': 5,
#   'Wind Speed': 9.24,
#   'Current Description': 'light rain'},
#  {'City': 'Qaanaaq',
#   'Country': 'GL',
#   'Lat': 77.484,
#   'Lng': -69.3632,
#   'Max Temp': 38.91,
#   'Humidity': 69,
#   'Cloudiness': 100,
#   'Wind Speed': 1.36,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Nizwa',
#   'Country': 'OM',
#   'Lat': 22.9333,
#   'Lng': 57.5333,
#   'Max Temp': 88.61,
#   'Humidity': 47,
#   'Cloudiness': 14,
#   'Wind Speed': 5.01,
#   'Current Description': 'few clouds'},
#  {'City': 'Port Said',
#   'Country': 'EG',
#   'Lat': 31.2565,
#   'Lng': 32.2841,
#   'Max Temp': 79.43,
#   'Humidity': 75,
#   'Cloudiness': 6,
#   'Wind Speed': 8.9,
#   'Current Description': 'clear sky'},
#  {'City': 'Eenhana',
#   'Country': 'NA',
#   'Lat': -17.4667,
#   'Lng': 16.3333,
#   'Max Temp': 52.57,
#   'Humidity': 53,
#   'Cloudiness': 0,
#   'Wind Speed': 8.61,
#   'Current Description': 'clear sky'},
#  {'City': 'Tuatapere',
#   'Country': 'NZ',
#   'Lat': -46.1333,
#   'Lng': 167.6833,
#   'Max Temp': 49.82,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 0.45,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Pemangkat',
#   'Country': 'ID',
#   'Lat': 1.1667,
#   'Lng': 108.9667,
#   'Max Temp': 83.5,
#   'Humidity': 76,
#   'Cloudiness': 36,
#   'Wind Speed': 6.31,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Mahebourg',
#   'Country': 'MU',
#   'Lat': -20.4081,
#   'Lng': 57.7,
#   'Max Temp': 69.48,
#   'Humidity': 63,
#   'Cloudiness': 7,
#   'Wind Speed': 11.1,
#   'Current Description': 'clear sky'},
#  {'City': 'Cidreira',
#   'Country': 'BR',
#   'Lat': -30.1811,
#   'Lng': -50.2056,
#   'Max Temp': 67.53,
#   'Humidity': 70,
#   'Cloudiness': 83,
#   'Wind Speed': 5.39,
#   'Current Description': 'broken clouds'},
#  {'City': 'Luderitz',
#   'Country': 'NA',
#   'Lat': -26.6481,
#   'Lng': 15.1594,
#   'Max Temp': 65.26,
#   'Humidity': 27,
#   'Cloudiness': 82,
#   'Wind Speed': 10.42,
#   'Current Description': 'broken clouds'},
#  {'City': 'Vardo',
#   'Country': 'NO',
#   'Lat': 70.3705,
#   'Lng': 31.1107,
#   'Max Temp': 45.9,
#   'Humidity': 76,
#   'Cloudiness': 65,
#   'Wind Speed': 21.41,
#   'Current Description': 'broken clouds'},
#  {'City': 'Mar Del Plata',
#   'Country': 'AR',
#   'Lat': -38.0023,
#   'Lng': -57.5575,
#   'Max Temp': 47.12,
#   'Humidity': 44,
#   'Cloudiness': 99,
#   'Wind Speed': 7,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Honiara',
#   'Country': 'SB',
#   'Lat': -9.4333,
#   'Lng': 159.95,
#   'Max Temp': 84.15,
#   'Humidity': 71,
#   'Cloudiness': 87,
#   'Wind Speed': 5.64,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Barrow',
#   'Country': 'US',
#   'Lat': 71.2906,
#   'Lng': -156.7887,
#   'Max Temp': 39.22,
#   'Humidity': 95,
#   'Cloudiness': 90,
#   'Wind Speed': 17.27,
#   'Current Description': 'moderate rain'},
#  {'City': 'Tuktoyaktuk',
#   'Country': 'CA',
#   'Lat': 69.4541,
#   'Lng': -133.0374,
#   'Max Temp': 44.06,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 11.3,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ponta Do Sol',
#   'Country': 'PT',
#   'Lat': 32.6667,
#   'Lng': -17.1,
#   'Max Temp': 75,
#   'Humidity': 81,
#   'Cloudiness': 3,
#   'Wind Speed': 2.21,
#   'Current Description': 'clear sky'},
#  {'City': 'Gat',
#   'Country': 'IL',
#   'Lat': 31.61,
#   'Lng': 34.7642,
#   'Max Temp': 79.48,
#   'Humidity': 84,
#   'Cloudiness': 18,
#   'Wind Speed': 3.62,
#   'Current Description': 'few clouds'},
#  {'City': 'Araouane',
#   'Country': 'ML',
#   'Lat': 18.9048,
#   'Lng': -3.5265,
#   'Max Temp': 94.98,
#   'Humidity': 31,
#   'Cloudiness': 18,
#   'Wind Speed': 11.97,
#   'Current Description': 'few clouds'},
#  {'City': 'Motril',
#   'Country': 'ES',
#   'Lat': 36.7507,
#   'Lng': -3.5179,
#   'Max Temp': 79.3,
#   'Humidity': 59,
#   'Cloudiness': 0,
#   'Wind Speed': 6.15,
#   'Current Description': 'clear sky'},
#  {'City': 'Vao',
#   'Country': 'NC',
#   'Lat': -22.6667,
#   'Lng': 167.4833,
#   'Max Temp': 70.72,
#   'Humidity': 65,
#   'Cloudiness': 87,
#   'Wind Speed': 19.62,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Lebu',
#   'Country': 'CL',
#   'Lat': -37.6167,
#   'Lng': -73.65,
#   'Max Temp': 48.42,
#   'Humidity': 82,
#   'Cloudiness': 26,
#   'Wind Speed': 17.6,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Mankato',
#   'Country': 'US',
#   'Lat': 44.1636,
#   'Lng': -93.9994,
#   'Max Temp': 79.68,
#   'Humidity': 82,
#   'Cloudiness': 1,
#   'Wind Speed': 5.75,
#   'Current Description': 'clear sky'},
#  {'City': 'Yuzhno-Sukhokumsk',
#   'Country': 'RU',
#   'Lat': 44.6581,
#   'Lng': 45.6436,
#   'Max Temp': 76.44,
#   'Humidity': 49,
#   'Cloudiness': 69,
#   'Wind Speed': 7.76,
#   'Current Description': 'broken clouds'},
#  {'City': 'Pozo Colorado',
#   'Country': 'PY',
#   'Lat': -23.4923,
#   'Lng': -58.7972,
#   'Max Temp': 77.29,
#   'Humidity': 39,
#   'Cloudiness': 52,
#   'Wind Speed': 6.55,
#   'Current Description': 'broken clouds'},
#  {'City': 'Salinopolis',
#   'Country': 'BR',
#   'Lat': -0.6136,
#   'Lng': -47.3561,
#   'Max Temp': 78.67,
#   'Humidity': 81,
#   'Cloudiness': 25,
#   'Wind Speed': 9.08,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Kushalgarh',
#   'Country': 'IN',
#   'Lat': 23.199,
#   'Lng': 74.4507,
#   'Max Temp': 75.2,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 13.31,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Panguipulli',
#   'Country': 'CL',
#   'Lat': -39.6333,
#   'Lng': -72.3333,
#   'Max Temp': 37.33,
#   'Humidity': 97,
#   'Cloudiness': 38,
#   'Wind Speed': 2.75,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Rabo De Peixe',
#   'Country': 'PT',
#   'Lat': 37.8,
#   'Lng': -25.5833,
#   'Max Temp': 67.51,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Current Description': 'light intensity drizzle'},
#  {'City': 'Shchigry',
#   'Country': 'RU',
#   'Lat': 51.8755,
#   'Lng': 36.9043,
#   'Max Temp': 60.62,
#   'Humidity': 64,
#   'Cloudiness': 60,
#   'Wind Speed': 4.23,
#   'Current Description': 'broken clouds'},
#  {'City': 'Juneau',
#   'Country': 'US',
#   'Lat': 58.3019,
#   'Lng': -134.4197,
#   'Max Temp': 59.85,
#   'Humidity': 85,
#   'Cloudiness': 90,
#   'Wind Speed': 2.73,
#   'Current Description': 'light rain'},
#  {'City': 'Amga',
#   'Country': 'RU',
#   'Lat': 60.8953,
#   'Lng': 131.9608,
#   'Max Temp': 76.05,
#   'Humidity': 39,
#   'Cloudiness': 0,
#   'Wind Speed': 7.29,
#   'Current Description': 'clear sky'},
#  {'City': 'Byron Bay',
#   'Country': 'AU',
#   'Lat': -28.65,
#   'Lng': 153.6167,
#   'Max Temp': 69.06,
#   'Humidity': 33,
#   'Cloudiness': 34,
#   'Wind Speed': 0.92,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Chuy',
#   'Country': 'UY',
#   'Lat': -33.6971,
#   'Lng': -53.4616,
#   'Max Temp': 58.37,
#   'Humidity': 97,
#   'Cloudiness': 3,
#   'Wind Speed': 4.9,
#   'Current Description': 'clear sky'},
#  {'City': 'Carnarvon',
#   'Country': 'AU',
#   'Lat': -24.8667,
#   'Lng': 113.6333,
#   'Max Temp': 66.56,
#   'Humidity': 61,
#   'Cloudiness': 8,
#   'Wind Speed': 3.65,
#   'Current Description': 'clear sky'},
#  {'City': 'Kodiak',
#   'Country': 'US',
#   'Lat': 57.79,
#   'Lng': -152.4072,
#   'Max Temp': 56.71,
#   'Humidity': 72,
#   'Cloudiness': 1,
#   'Wind Speed': 9.22,
#   'Current Description': 'clear sky'},
#  {'City': 'Okhotsk',
#   'Country': 'RU',
#   'Lat': 59.3833,
#   'Lng': 143.3,
#   'Max Temp': 57.92,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 0.98,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Dallas',
#   'Country': 'US',
#   'Lat': 32.7668,
#   'Lng': -96.7836,
#   'Max Temp': 94.01,
#   'Humidity': 59,
#   'Cloudiness': 1,
#   'Wind Speed': 1.01,
#   'Current Description': 'clear sky'},
#  {'City': 'Maceio',
#   'Country': 'BR',
#   'Lat': -9.6658,
#   'Lng': -35.7353,
#   'Max Temp': 72.84,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Current Description': 'broken clouds'},
#  {'City': 'Eyl',
#   'Country': 'SO',
#   'Lat': 7.9803,
#   'Lng': 49.8164,
#   'Max Temp': 78.71,
#   'Humidity': 63,
#   'Cloudiness': 98,
#   'Wind Speed': 22.59,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Portage',
#   'Country': 'US',
#   'Lat': 41.1667,
#   'Lng': -81.1998,
#   'Max Temp': 74.66,
#   'Humidity': 72,
#   'Cloudiness': 1,
#   'Wind Speed': 0,
#   'Current Description': 'clear sky'},
#  {'City': 'Lac Du Bonnet',
#   'Country': 'CA',
#   'Lat': 50.2536,
#   'Lng': -96.0612,
#   'Max Temp': 77.76,
#   'Humidity': 50,
#   'Cloudiness': 23,
#   'Wind Speed': 3.09,
#   'Current Description': 'few clouds'},
#  {'City': 'Adrar',
#   'Country': 'MR',
#   'Lat': 20.5022,
#   'Lng': -10.0711,
#   'Max Temp': 88.39,
#   'Humidity': 20,
#   'Cloudiness': 0,
#   'Wind Speed': 8.95,
#   'Current Description': 'clear sky'},
#  {'City': 'La Orilla',
#   'Country': 'MX',
#   'Lat': 17.9833,
#   'Lng': -102.2333,
#   'Max Temp': 81.25,
#   'Humidity': 84,
#   'Cloudiness': 98,
#   'Wind Speed': 4.63,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Sernovodsk',
#   'Country': 'RU',
#   'Lat': 43.3117,
#   'Lng': 45.1594,
#   'Max Temp': 68.99,
#   'Humidity': 81,
#   'Cloudiness': 24,
#   'Wind Speed': 0.58,
#   'Current Description': 'few clouds'},
#  {'City': 'Inverell',
#   'Country': 'AU',
#   'Lat': -29.7833,
#   'Lng': 151.1167,
#   'Max Temp': 58.66,
#   'Humidity': 57,
#   'Cloudiness': 97,
#   'Wind Speed': 7,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mezen',
#   'Country': 'RU',
#   'Lat': 65.8522,
#   'Lng': 44.24,
#   'Max Temp': 48.99,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 8.79,
#   'Current Description': 'light rain'},
#  {'City': 'Moron',
#   'Country': 'AR',
#   'Lat': -34.6534,
#   'Lng': -58.6198,
#   'Max Temp': 55.96,
#   'Humidity': 94,
#   'Cloudiness': 0,
#   'Wind Speed': 3,
#   'Current Description': 'clear sky'},
#  {'City': 'Sinnamary',
#   'Country': 'GF',
#   'Lat': 5.3833,
#   'Lng': -52.95,
#   'Max Temp': 77.4,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 6.62,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mayya',
#   'Country': 'RU',
#   'Lat': 61.7333,
#   'Lng': 130.2811,
#   'Max Temp': 76.32,
#   'Humidity': 37,
#   'Cloudiness': 0,
#   'Wind Speed': 7.23,
#   'Current Description': 'clear sky'},
#  {'City': 'Wanaka',
#   'Country': 'NZ',
#   'Lat': -44.7,
#   'Lng': 169.15,
#   'Max Temp': 43.61,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 4.52,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mariental',
#   'Country': 'NA',
#   'Lat': -24.6333,
#   'Lng': 17.9667,
#   'Max Temp': 49.32,
#   'Humidity': 53,
#   'Cloudiness': 52,
#   'Wind Speed': 13.2,
#   'Current Description': 'broken clouds'},
#  {'City': 'Caravelas',
#   'Country': 'BR',
#   'Lat': -17.7125,
#   'Lng': -39.2481,
#   'Max Temp': 68.83,
#   'Humidity': 84,
#   'Cloudiness': 2,
#   'Wind Speed': 5.61,
#   'Current Description': 'clear sky'},
#  {'City': 'Balaka',
#   'Country': 'MW',
#   'Lat': -14.9793,
#   'Lng': 34.9558,
#   'Max Temp': 52.27,
#   'Humidity': 94,
#   'Cloudiness': 2,
#   'Wind Speed': 7.34,
#   'Current Description': 'clear sky'},
#  {'City': 'Murgab',
#   'Country': 'TM',
#   'Lat': 37.4966,
#   'Lng': 61.9714,
#   'Max Temp': 82.27,
#   'Humidity': 36,
#   'Cloudiness': 0,
#   'Wind Speed': 11.5,
#   'Current Description': 'clear sky'},
#  {'City': 'Kawalu',
#   'Country': 'ID',
#   'Lat': -7.3817,
#   'Lng': 108.2082,
#   'Max Temp': 78.69,
#   'Humidity': 63,
#   'Cloudiness': 8,
#   'Wind Speed': 2.8,
#   'Current Description': 'clear sky'},
#  {'City': 'Vavuniya',
#   'Country': 'LK',
#   'Lat': 8.7514,
#   'Lng': 80.4971,
#   'Max Temp': 81.52,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 9.22,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Asau',
#   'Country': 'RO',
#   'Lat': 46.4333,
#   'Lng': 26.4,
#   'Max Temp': 64.76,
#   'Humidity': 82,
#   'Cloudiness': 4,
#   'Wind Speed': 3.96,
#   'Current Description': 'clear sky'},
#  {'City': 'Cap Malheureux',
#   'Country': 'MU',
#   'Lat': -19.9842,
#   'Lng': 57.6142,
#   'Max Temp': 71.51,
#   'Humidity': 59,
#   'Cloudiness': 0,
#   'Wind Speed': 15.41,
#   'Current Description': 'clear sky'},
#  {'City': 'Bani',
#   'Country': 'DO',
#   'Lat': 18.2833,
#   'Lng': -70.3333,
#   'Max Temp': 77.49,
#   'Humidity': 86,
#   'Cloudiness': 18,
#   'Wind Speed': 3.44,
#   'Current Description': 'few clouds'},
#  {'City': 'Sobolevo',
#   'Country': 'RU',
#   'Lat': 54.4299,
#   'Lng': 31.8996,
#   'Max Temp': 61.41,
#   'Humidity': 75,
#   'Cloudiness': 55,
#   'Wind Speed': 4.45,
#   'Current Description': 'broken clouds'},
#  {'City': 'Yavoriv',
#   'Country': 'UA',
#   'Lat': 49.9386,
#   'Lng': 23.3825,
#   'Max Temp': 65.48,
#   'Humidity': 85,
#   'Cloudiness': 99,
#   'Wind Speed': 7.02,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Provideniya',
#   'Country': 'RU',
#   'Lat': 64.3833,
#   'Lng': -173.3,
#   'Max Temp': 50.11,
#   'Humidity': 81,
#   'Cloudiness': 90,
#   'Wind Speed': 4.47,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Beidao',
#   'Country': 'CN',
#   'Lat': 34.5686,
#   'Lng': 105.8933,
#   'Max Temp': 69.75,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 4.03,
#   'Current Description': 'light rain'},
#  {'City': 'Sorong',
#   'Country': 'ID',
#   'Lat': -0.8833,
#   'Lng': 131.25,
#   'Max Temp': 83.55,
#   'Humidity': 66,
#   'Cloudiness': 100,
#   'Wind Speed': 7.85,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Maryville',
#   'Country': 'US',
#   'Lat': 35.7565,
#   'Lng': -83.9705,
#   'Max Temp': 82.11,
#   'Humidity': 84,
#   'Cloudiness': 75,
#   'Wind Speed': 5.75,
#   'Current Description': 'broken clouds'},
#  {'City': 'Vila',
#   'Country': 'PT',
#   'Lat': 42.0304,
#   'Lng': -8.1588,
#   'Max Temp': 54.73,
#   'Humidity': 91,
#   'Cloudiness': 0,
#   'Wind Speed': 3.74,
#   'Current Description': 'clear sky'},
#  {'City': 'Tabou',
#   'Country': 'CI',
#   'Lat': 4.423,
#   'Lng': -7.3528,
#   'Max Temp': 76.08,
#   'Humidity': 75,
#   'Cloudiness': 39,
#   'Wind Speed': 7.34,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Gazli',
#   'Country': 'UZ',
#   'Lat': 40.1333,
#   'Lng': 63.45,
#   'Max Temp': 91.53,
#   'Humidity': 15,
#   'Cloudiness': 0,
#   'Wind Speed': 9.91,
#   'Current Description': 'clear sky'},
#  {'City': 'Seminole',
#   'Country': 'US',
#   'Lat': 28.7086,
#   'Lng': -81.2081,
#   'Max Temp': 83.37,
#   'Humidity': 87,
#   'Cloudiness': 1,
#   'Wind Speed': 5.75,
#   'Current Description': 'clear sky'},
#  {'City': 'Toba Tek Singh',
#   'Country': 'PK',
#   'Lat': 30.9743,
#   'Lng': 72.4827,
#   'Max Temp': 97.75,
#   'Humidity': 42,
#   'Cloudiness': 91,
#   'Wind Speed': 10.09,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Touros',
#   'Country': 'BR',
#   'Lat': -5.1989,
#   'Lng': -35.4608,
#   'Max Temp': 74.3,
#   'Humidity': 89,
#   'Cloudiness': 0,
#   'Wind Speed': 9.78,
#   'Current Description': 'clear sky'},
#  {'City': 'Pedasi',
#   'Country': 'PA',
#   'Lat': 7.5333,
#   'Lng': -80.0333,
#   'Max Temp': 76.46,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 5.82,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Lagoa',
#   'Country': 'PT',
#   'Lat': 39.05,
#   'Lng': -27.9833,
#   'Max Temp': 68.85,
#   'Humidity': 84,
#   'Cloudiness': 9,
#   'Wind Speed': 11.65,
#   'Current Description': 'clear sky'},
#  {'City': 'Kollam',
#   'Country': 'IN',
#   'Lat': 8.8833,
#   'Lng': 76.6,
#   'Max Temp': 76.87,
#   'Humidity': 89,
#   'Cloudiness': 97,
#   'Wind Speed': 12.8,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Oistins',
#   'Country': 'BB',
#   'Lat': 13.0667,
#   'Lng': -59.5333,
#   'Max Temp': 80.64,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 12.75,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Upernavik',
#   'Country': 'GL',
#   'Lat': 72.7868,
#   'Lng': -56.1549,
#   'Max Temp': 42.71,
#   'Humidity': 74,
#   'Cloudiness': 99,
#   'Wind Speed': 3.83,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mancora',
#   'Country': 'PE',
#   'Lat': -4.1078,
#   'Lng': -81.0475,
#   'Max Temp': 69.44,
#   'Humidity': 82,
#   'Cloudiness': 76,
#   'Wind Speed': 9.86,
#   'Current Description': 'broken clouds'},
#  {'City': 'South Sioux City',
#   'Country': 'US',
#   'Lat': 42.4739,
#   'Lng': -96.4136,
#   'Max Temp': 82.2,
#   'Humidity': 59,
#   'Cloudiness': 1,
#   'Wind Speed': 1.01,
#   'Current Description': 'clear sky'},
#  {'City': 'Mount Isa',
#   'Country': 'AU',
#   'Lat': -20.7333,
#   'Lng': 139.5,
#   'Max Temp': 71.37,
#   'Humidity': 21,
#   'Cloudiness': 68,
#   'Wind Speed': 13.8,
#   'Current Description': 'broken clouds'},
#  {'City': 'Dikson',
#   'Country': 'RU',
#   'Lat': 73.5069,
#   'Lng': 80.5464,
#   'Max Temp': 44.71,
#   'Humidity': 72,
#   'Cloudiness': 37,
#   'Wind Speed': 7.67,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Port Elizabeth',
#   'Country': 'ZA',
#   'Lat': -33.918,
#   'Lng': 25.5701,
#   'Max Temp': 54.1,
#   'Humidity': 37,
#   'Cloudiness': 99,
#   'Wind Speed': 10.71,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kalat',
#   'Country': 'PK',
#   'Lat': 29.0225,
#   'Lng': 66.5916,
#   'Max Temp': 77.95,
#   'Humidity': 26,
#   'Cloudiness': 74,
#   'Wind Speed': 2.01,
#   'Current Description': 'broken clouds'},
#  {'City': 'Iquitos',
#   'Country': 'PE',
#   'Lat': -3.7481,
#   'Lng': -73.2472,
#   'Max Temp': 75.24,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 2.3,
#   'Current Description': 'broken clouds'},
#  {'City': 'Piotrkow Trybunalski',
#   'Country': 'PL',
#   'Lat': 51.4055,
#   'Lng': 19.7032,
#   'Max Temp': 68.11,
#   'Humidity': 10,
#   'Cloudiness': 28,
#   'Wind Speed': 7.09,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Plettenberg Bay',
#   'Country': 'ZA',
#   'Lat': -34.0527,
#   'Lng': 23.3716,
#   'Max Temp': 61.23,
#   'Humidity': 40,
#   'Cloudiness': 86,
#   'Wind Speed': 10.33,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kavaratti',
#   'Country': 'IN',
#   'Lat': 10.5669,
#   'Lng': 72.642,
#   'Max Temp': 81.55,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 20.24,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Saldanha',
#   'Country': 'ZA',
#   'Lat': -33.0117,
#   'Lng': 17.9442,
#   'Max Temp': 62.91,
#   'Humidity': 41,
#   'Cloudiness': 100,
#   'Wind Speed': 20.89,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Cayeli',
#   'Country': 'TR',
#   'Lat': 41.0923,
#   'Lng': 40.7292,
#   'Max Temp': 72.63,
#   'Humidity': 83,
#   'Cloudiness': 55,
#   'Wind Speed': 3.36,
#   'Current Description': 'broken clouds'},
#  {'City': 'Ribeira Grande',
#   'Country': 'PT',
#   'Lat': 38.5167,
#   'Lng': -28.7,
#   'Max Temp': 70.23,
#   'Humidity': 84,
#   'Cloudiness': 5,
#   'Wind Speed': 15.23,
#   'Current Description': 'clear sky'},
#  {'City': 'Deputatskiy',
#   'Country': 'RU',
#   'Lat': 69.3,
#   'Lng': 139.9,
#   'Max Temp': 57.31,
#   'Humidity': 53,
#   'Cloudiness': 100,
#   'Wind Speed': 5.17,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Cape Town',
#   'Country': 'ZA',
#   'Lat': -33.9258,
#   'Lng': 18.4232,
#   'Max Temp': 57.61,
#   'Humidity': 15,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Current Description': 'clear sky'},
#  {'City': 'Faya',
#   'Country': 'SA',
#   'Lat': 18.3851,
#   'Lng': 42.4509,
#   'Max Temp': 63.12,
#   'Humidity': 70,
#   'Cloudiness': 91,
#   'Wind Speed': 4.38,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Pasighat',
#   'Country': 'IN',
#   'Lat': 28.0667,
#   'Lng': 95.3333,
#   'Max Temp': 79.47,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 1.95,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Brenham',
#   'Country': 'US',
#   'Lat': 30.1669,
#   'Lng': -96.3977,
#   'Max Temp': 86.4,
#   'Humidity': 72,
#   'Cloudiness': 1,
#   'Wind Speed': 0,
#   'Current Description': 'clear sky'},
#  {'City': 'Kupang',
#   'Country': 'ID',
#   'Lat': -10.1667,
#   'Lng': 123.5833,
#   'Max Temp': 82.98,
#   'Humidity': 57,
#   'Cloudiness': 20,
#   'Wind Speed': 5.75,
#   'Current Description': 'few clouds'},
#  {'City': 'Lewiston',
#   'Country': 'US',
#   'Lat': 44.1003,
#   'Lng': -70.2148,
#   'Max Temp': 69.46,
#   'Humidity': 98,
#   'Cloudiness': 75,
#   'Wind Speed': 0,
#   'Current Description': 'mist'},
#  {'City': 'Itarema',
#   'Country': 'BR',
#   'Lat': -2.9248,
#   'Lng': -39.9167,
#   'Max Temp': 77.72,
#   'Humidity': 82,
#   'Cloudiness': 6,
#   'Wind Speed': 16.22,
#   'Current Description': 'clear sky'},
#  {'City': 'Asyut',
#   'Country': 'EG',
#   'Lat': 27.181,
#   'Lng': 31.1837,
#   'Max Temp': 78.91,
#   'Humidity': 54,
#   'Cloudiness': 0,
#   'Wind Speed': 9.35,
#   'Current Description': 'clear sky'},
#  {'City': 'Caceres',
#   'Country': 'ES',
#   'Lat': 39.522,
#   'Lng': -6.3748,
#   'Max Temp': 65.8,
#   'Humidity': 85,
#   'Cloudiness': 0,
#   'Wind Speed': 6.26,
#   'Current Description': 'clear sky'},
#  {'City': 'Batagay',
#   'Country': 'RU',
#   'Lat': 67.6333,
#   'Lng': 134.6333,
#   'Max Temp': 69.33,
#   'Humidity': 45,
#   'Cloudiness': 85,
#   'Wind Speed': 2.55,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Urmary',
#   'Country': 'RU',
#   'Lat': 55.6789,
#   'Lng': 47.944,
#   'Max Temp': 57.18,
#   'Humidity': 77,
#   'Cloudiness': 41,
#   'Wind Speed': 5.44,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Frickenhausen',
#   'Country': 'DE',
#   'Lat': 48.5935,
#   'Lng': 9.3601,
#   'Max Temp': 62.19,
#   'Humidity': 89,
#   'Cloudiness': 0,
#   'Wind Speed': 2.3,
#   'Current Description': 'clear sky'},
#  {'City': 'Kaitangata',
#   'Country': 'NZ',
#   'Lat': -46.2817,
#   'Lng': 169.8464,
#   'Max Temp': 51.93,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 4.68,
#   'Current Description': 'light rain'},
#  {'City': 'Bonga',
#   'Country': 'ET',
#   'Lat': 7.2833,
#   'Lng': 36.2333,
#   'Max Temp': 58.42,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 1.88,
#   'Current Description': 'light rain'},
#  {'City': 'Wagar',
#   'Country': 'SD',
#   'Lat': 16.1525,
#   'Lng': 36.2032,
#   'Max Temp': 78.08,
#   'Humidity': 79,
#   'Cloudiness': 42,
#   'Wind Speed': 15.5,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Porto Novo',
#   'Country': 'BJ',
#   'Lat': 6.4965,
#   'Lng': 2.6036,
#   'Max Temp': 74.19,
#   'Humidity': 80,
#   'Cloudiness': 38,
#   'Wind Speed': 7.65,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Palmer',
#   'Country': 'US',
#   'Lat': 42.1584,
#   'Lng': -72.3287,
#   'Max Temp': 73.27,
#   'Humidity': 84,
#   'Cloudiness': 75,
#   'Wind Speed': 1.01,
#   'Current Description': 'broken clouds'},
#  {'City': 'Rio Gallegos',
#   'Country': 'AR',
#   'Lat': -51.6226,
#   'Lng': -69.2181,
#   'Max Temp': 34.48,
#   'Humidity': 82,
#   'Cloudiness': 38,
#   'Wind Speed': 21.81,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Mao',
#   'Country': 'ES',
#   'Lat': 39.8885,
#   'Lng': 4.2658,
#   'Max Temp': 70.36,
#   'Humidity': 83,
#   'Cloudiness': 0,
#   'Wind Speed': 5.75,
#   'Current Description': 'clear sky'},
#  {'City': 'Samarai',
#   'Country': 'PG',
#   'Lat': -10.6167,
#   'Lng': 150.6667,
#   'Max Temp': 79.68,
#   'Humidity': 74,
#   'Cloudiness': 94,
#   'Wind Speed': 16.2,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Monforte De Lemos',
#   'Country': 'ES',
#   'Lat': 42.5216,
#   'Lng': -7.5142,
#   'Max Temp': 62.28,
#   'Humidity': 98,
#   'Cloudiness': 4,
#   'Wind Speed': 0.85,
#   'Current Description': 'clear sky'},
#  {'City': 'Ostrovnoy',
#   'Country': 'RU',
#   'Lat': 68.0531,
#   'Lng': 39.5131,
#   'Max Temp': 45.52,
#   'Humidity': 83,
#   'Cloudiness': 88,
#   'Wind Speed': 19.26,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Comodoro Rivadavia',
#   'Country': 'AR',
#   'Lat': -45.8667,
#   'Lng': -67.5,
#   'Max Temp': 42.66,
#   'Humidity': 52,
#   'Cloudiness': 0,
#   'Wind Speed': 11.5,
#   'Current Description': 'clear sky'},
#  {'City': 'Daru',
#   'Country': 'PG',
#   'Lat': -9.0763,
#   'Lng': 143.2092,
#   'Max Temp': 77.81,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 13.53,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Emba',
#   'Country': 'KZ',
#   'Lat': 48.8264,
#   'Lng': 58.1442,
#   'Max Temp': 71.35,
#   'Humidity': 47,
#   'Cloudiness': 0,
#   'Wind Speed': 6.6,
#   'Current Description': 'clear sky'},
#  {'City': 'Kahului',
#   'Country': 'US',
#   'Lat': 20.8947,
#   'Lng': -156.47,
#   'Max Temp': 83.46,
#   'Humidity': 92,
#   'Cloudiness': 34,
#   'Wind Speed': 8.99,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Umm Kaddadah',
#   'Country': 'SD',
#   'Lat': 13.6017,
#   'Lng': 26.6876,
#   'Max Temp': 81.77,
#   'Humidity': 59,
#   'Cloudiness': 93,
#   'Wind Speed': 13.13,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Katsuura',
#   'Country': 'JP',
#   'Lat': 35.1333,
#   'Lng': 140.3,
#   'Max Temp': 84.31,
#   'Humidity': 64,
#   'Cloudiness': 57,
#   'Wind Speed': 20.58,
#   'Current Description': 'broken clouds'},
#  {'City': 'Grootegast',
#   'Country': 'NL',
#   'Lat': 53.2125,
#   'Lng': 6.2736,
#   'Max Temp': 64.96,
#   'Humidity': 54,
#   'Cloudiness': 60,
#   'Wind Speed': 5.48,
#   'Current Description': 'broken clouds'},
#  {'City': 'Seoul',
#   'Country': 'KR',
#   'Lat': 37.5683,
#   'Lng': 126.9778,
#   'Max Temp': 92.59,
#   'Humidity': 37,
#   'Cloudiness': 3,
#   'Wind Speed': 6.42,
#   'Current Description': 'clear sky'},
#  {'City': 'Hambantota',
#   'Country': 'LK',
#   'Lat': 6.1241,
#   'Lng': 81.1185,
#   'Max Temp': 77.34,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Current Description': 'broken clouds'},
#  {'City': 'Tortosa',
#   'Country': 'ES',
#   'Lat': 40.8125,
#   'Lng': 0.5216,
#   'Max Temp': 77.18,
#   'Humidity': 76,
#   'Cloudiness': 72,
#   'Wind Speed': 2.95,
#   'Current Description': 'broken clouds'},
#  {'City': 'Piet Retief',
#   'Country': 'ZA',
#   'Lat': -27.0071,
#   'Lng': 30.8132,
#   'Max Temp': 33.91,
#   'Humidity': 95,
#   'Cloudiness': 0,
#   'Wind Speed': 3.4,
#   'Current Description': 'clear sky'},
#  {'City': 'Tshikapa',
#   'Country': 'CD',
#   'Lat': -6.4167,
#   'Lng': 20.8,
#   'Max Temp': 68.2,
#   'Humidity': 40,
#   'Cloudiness': 78,
#   'Wind Speed': 3.15,
#   'Current Description': 'broken clouds'},
#  {'City': 'Boyuibe',
#   'Country': 'BO',
#   'Lat': -20.4167,
# ...
#   'Max Temp': 71.73,
#   'Humidity': 94,
#   'Cloudiness': 69,
#   'Wind Speed': 1.66,
#   'Current Description': 'broken clouds'},
#  {'City': 'Mayor Pablo Lagerenza',
#   'Country': 'PY',
#   'Lat': -19.9309,
#   'Lng': -60.7718,
#   'Max Temp': 77.14,
#   'Humidity': 36,
#   'Cloudiness': 7,
#   'Wind Speed': 4.94,
#   'Current Description': 'clear sky'},
#  {'City': 'Mount Gambier',
#   'Country': 'AU',
#   'Lat': -37.8333,
#   'Lng': 140.7667,
#   'Max Temp': 57.11,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 17.27,
#   'Current Description': 'light rain'},
#  {'City': 'Rocha',
#   'Country': 'UY',
#   'Lat': -34.4833,
#   'Lng': -54.3333,
#   'Max Temp': 57.06,
#   'Humidity': 94,
#   'Cloudiness': 86,
#   'Wind Speed': 9.6,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Sapucai',
#   'Country': 'PY',
#   'Lat': -25.6667,
#   'Lng': -56.9167,
#   'Max Temp': 74.55,
#   'Humidity': 44,
#   'Cloudiness': 100,
#   'Wind Speed': 3.98,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Puerto Escondido',
#   'Country': 'MX',
#   'Lat': 15.85,
#   'Lng': -97.0667,
#   'Max Temp': 85.03,
#   'Humidity': 65,
#   'Cloudiness': 90,
#   'Wind Speed': 0,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Grants',
#   'Country': 'US',
#   'Lat': 35.1473,
#   'Lng': -107.8514,
#   'Max Temp': 64.63,
#   'Humidity': 82,
#   'Cloudiness': 1,
#   'Wind Speed': 8.05,
#   'Current Description': 'clear sky'},
#  {'City': 'Srednekolymsk',
#   'Country': 'RU',
#   'Lat': 67.45,
#   'Lng': 153.6833,
#   'Max Temp': 57.38,
#   'Humidity': 39,
#   'Cloudiness': 63,
#   'Wind Speed': 15.37,
#   'Current Description': 'broken clouds'},
#  {'City': 'Beyneu',
#   'Country': 'KZ',
#   'Lat': 45.3167,
#   'Lng': 55.2,
#   'Max Temp': 81.5,
#   'Humidity': 25,
#   'Cloudiness': 21,
#   'Wind Speed': 11.81,
#   'Current Description': 'few clouds'},
#  {'City': 'Sebring',
#   'Country': 'US',
#   'Lat': 27.4956,
#   'Lng': -81.4409,
#   'Max Temp': 82.35,
#   'Humidity': 88,
#   'Cloudiness': 90,
#   'Wind Speed': 3,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tessalit',
#   'Country': 'ML',
#   'Lat': 20.1986,
#   'Lng': 1.0114,
#   'Max Temp': 91.78,
#   'Humidity': 32,
#   'Cloudiness': 88,
#   'Wind Speed': 8.55,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Sindor',
#   'Country': 'RU',
#   'Lat': 62.8629,
#   'Lng': 51.8905,
#   'Max Temp': 50.56,
#   'Humidity': 86,
#   'Cloudiness': 81,
#   'Wind Speed': 3.51,
#   'Current Description': 'broken clouds'},
#  {'City': 'Port Augusta',
#   'Country': 'AU',
#   'Lat': -32.5,
#   'Lng': 137.7667,
#   'Max Temp': 62.74,
#   'Humidity': 39,
#   'Cloudiness': 7,
#   'Wind Speed': 17.22,
#   'Current Description': 'clear sky'},
#  {'City': 'Lata',
#   'Country': 'PT',
#   'Lat': 40.1629,
#   'Lng': -8.3327,
#   'Max Temp': 66.04,
#   'Humidity': 97,
#   'Cloudiness': 98,
#   'Wind Speed': 2.95,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Pinyug',
#   'Country': 'RU',
#   'Lat': 60.251,
#   'Lng': 47.7842,
#   'Max Temp': 54.7,
#   'Humidity': 71,
#   'Cloudiness': 100,
#   'Wind Speed': 6.22,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Iqaluit',
#   'Country': 'CA',
#   'Lat': 63.7506,
#   'Lng': -68.5145,
#   'Max Temp': 49.69,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 5.99,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Dwarka',
#   'Country': 'IN',
#   'Lat': 22.2394,
#   'Lng': 68.9678,
#   'Max Temp': 81.9,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 23.96,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kalabo',
#   'Country': 'ZM',
#   'Lat': -14.97,
#   'Lng': 22.6814,
#   'Max Temp': 49.82,
#   'Humidity': 64,
#   'Cloudiness': 2,
#   'Wind Speed': 7,
#   'Current Description': 'clear sky'},
#  {'City': 'De Aar',
#   'Country': 'ZA',
#   'Lat': -30.6497,
#   'Lng': 24.0123,
#   'Max Temp': 37.56,
#   'Humidity': 33,
#   'Cloudiness': 18,
#   'Wind Speed': 6.04,
#   'Current Description': 'few clouds'},
#  {'City': 'Tual',
#   'Country': 'ID',
#   'Lat': -5.6667,
#   'Lng': 132.75,
#   'Max Temp': 79.84,
#   'Humidity': 79,
#   'Cloudiness': 85,
#   'Wind Speed': 22.73,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Henties Bay',
#   'Country': 'NA',
#   'Lat': -22.116,
#   'Lng': 14.2845,
#   'Max Temp': 73.02,
#   'Humidity': 33,
#   'Cloudiness': 35,
#   'Wind Speed': 22.46,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Kodinsk',
#   'Country': 'RU',
#   'Lat': 58.6881,
#   'Lng': 99.1844,
#   'Max Temp': 80.04,
#   'Humidity': 44,
#   'Cloudiness': 100,
#   'Wind Speed': 4.03,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Muzhi',
#   'Country': 'RU',
#   'Lat': 65.3667,
#   'Lng': 64.6667,
#   'Max Temp': 51.39,
#   'Humidity': 71,
#   'Cloudiness': 89,
#   'Wind Speed': 1.97,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Nanortalik',
#   'Country': 'GL',
#   'Lat': 60.1432,
#   'Lng': -45.2371,
#   'Max Temp': 44.15,
#   'Humidity': 75,
#   'Cloudiness': 91,
#   'Wind Speed': 11.12,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tupaciguara',
#   'Country': 'BR',
#   'Lat': -18.5922,
#   'Lng': -48.705,
#   'Max Temp': 61.14,
#   'Humidity': 49,
#   'Cloudiness': 0,
#   'Wind Speed': 5.59,
#   'Current Description': 'clear sky'},
#  {'City': 'Bandar-E Lengeh',
#   'Country': 'IR',
#   'Lat': 26.5579,
#   'Lng': 54.8807,
#   'Max Temp': 90.68,
#   'Humidity': 71,
#   'Cloudiness': 61,
#   'Wind Speed': 7.92,
#   'Current Description': 'broken clouds'},
#  {'City': 'Puerto Carreno',
#   'Country': 'CO',
#   'Lat': 6.189,
#   'Lng': -67.4859,
#   'Max Temp': 78.17,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 2.93,
#   'Current Description': 'overcast clouds'},
#  {'City': 'San Patricio',
#   'Country': 'US',
#   'Lat': 28.017,
#   'Lng': -97.5169,
#   'Max Temp': 84.29,
#   'Humidity': 73,
#   'Cloudiness': 3,
#   'Wind Speed': 9.64,
#   'Current Description': 'clear sky'},
#  {'City': 'Kismayo',
#   'Country': 'SO',
#   'Lat': -0.3582,
#   'Lng': 42.5454,
#   'Max Temp': 74.98,
#   'Humidity': 78,
#   'Cloudiness': 88,
#   'Wind Speed': 21.74,
#   'Current Description': 'light rain'},
#  {'City': 'San Gavino Monreale',
#   'Country': 'IT',
#   'Lat': 39.5514,
#   'Lng': 8.7917,
#   'Max Temp': 80.33,
#   'Humidity': 56,
#   'Cloudiness': 100,
#   'Wind Speed': 10.49,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Salalah',
#   'Country': 'OM',
#   'Lat': 17.0151,
#   'Lng': 54.0924,
#   'Max Temp': 78.89,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 5.75,
#   'Current Description': 'broken clouds'},
#  {'City': 'Methoni',
#   'Country': 'GR',
#   'Lat': 36.8197,
#   'Lng': 21.7049,
#   'Max Temp': 76.21,
#   'Humidity': 73,
#   'Cloudiness': 0,
#   'Wind Speed': 6.15,
#   'Current Description': 'clear sky'},
#  {'City': 'Hualmay',
#   'Country': 'PE',
#   'Lat': -11.0964,
#   'Lng': -77.6139,
#   'Max Temp': 63.39,
#   'Humidity': 85,
#   'Cloudiness': 12,
#   'Wind Speed': 9.71,
#   'Current Description': 'few clouds'},
#  {'City': 'Agadir',
#   'Country': 'MA',
#   'Lat': 30.4202,
#   'Lng': -9.5982,
#   'Max Temp': 66.65,
#   'Humidity': 79,
#   'Cloudiness': 0,
#   'Wind Speed': 4.5,
#   'Current Description': 'clear sky'},
#  {'City': 'General Roca',
#   'Country': 'AR',
#   'Lat': -39.0333,
#   'Lng': -67.5833,
#   'Max Temp': 45,
#   'Humidity': 71,
#   'Cloudiness': 58,
#   'Wind Speed': 9.24,
#   'Current Description': 'light rain'},
#  {'City': 'Varnavino',
#   'Country': 'RU',
#   'Lat': 57.4035,
#   'Lng': 45.0916,
#   'Max Temp': 56.19,
#   'Humidity': 65,
#   'Cloudiness': 95,
#   'Wind Speed': 3.74,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Jacareacanga',
#   'Country': 'BR',
#   'Lat': -6.2222,
#   'Lng': -57.7528,
#   'Max Temp': 75.52,
#   'Humidity': 52,
#   'Cloudiness': 12,
#   'Wind Speed': 1.72,
#   'Current Description': 'few clouds'},
#  {'City': 'Hailey',
#   'Country': 'US',
#   'Lat': 43.5196,
#   'Lng': -114.3153,
#   'Max Temp': 86.9,
#   'Humidity': 35,
#   'Cloudiness': 1,
#   'Wind Speed': 4.61,
#   'Current Description': 'smoke'},
#  {'City': 'Le Pradet',
#   'Country': 'FR',
#   'Lat': 43.1066,
#   'Lng': 6.0172,
#   'Max Temp': 73.63,
#   'Humidity': 73,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Current Description': 'clear sky'},
#  {'City': 'Aykhal',
#   'Country': 'RU',
#   'Lat': 66,
#   'Lng': 111.5,
#   'Max Temp': 79.52,
#   'Humidity': 46,
#   'Cloudiness': 11,
#   'Wind Speed': 12.28,
#   'Current Description': 'few clouds'},
#  {'City': 'Karpogory',
#   'Country': 'RU',
#   'Lat': 64.0019,
#   'Lng': 44.4451,
#   'Max Temp': 46.65,
#   'Humidity': 93,
#   'Cloudiness': 94,
#   'Wind Speed': 3.27,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Carauari',
#   'Country': 'BR',
#   'Lat': -4.8828,
#   'Lng': -66.8958,
#   'Max Temp': 76.55,
#   'Humidity': 72,
#   'Cloudiness': 35,
#   'Wind Speed': 2.44,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Carutapera',
#   'Country': 'BR',
#   'Lat': -1.195,
#   'Lng': -46.02,
#   'Max Temp': 75.83,
#   'Humidity': 87,
#   'Cloudiness': 13,
#   'Wind Speed': 4.99,
#   'Current Description': 'few clouds'},
#  {'City': 'College',
#   'Country': 'US',
#   'Lat': 64.8569,
#   'Lng': -147.8028,
#   'Max Temp': 72,
#   'Humidity': 53,
#   'Cloudiness': 75,
#   'Wind Speed': 3.44,
#   'Current Description': 'broken clouds'},
#  {'City': 'Ypsonas',
#   'Country': 'CY',
#   'Lat': 34.6884,
#   'Lng': 32.9574,
#   'Max Temp': 79,
#   'Humidity': 88,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Current Description': 'clear sky'},
#  {'City': 'Hovd',
#   'Country': 'MN',
#   'Lat': 48.0056,
#   'Lng': 91.6419,
#   'Max Temp': 68.92,
#   'Humidity': 48,
#   'Cloudiness': 23,
#   'Wind Speed': 3.85,
#   'Current Description': 'few clouds'},
#  {'City': 'Port Macquarie',
#   'Country': 'AU',
#   'Lat': -31.4333,
#   'Lng': 152.9167,
#   'Max Temp': 66.88,
#   'Humidity': 36,
#   'Cloudiness': 0,
#   'Wind Speed': 3.09,
#   'Current Description': 'clear sky'},
#  {'City': 'Manggar',
#   'Country': 'ID',
#   'Lat': -2.8833,
#   'Lng': 108.2667,
#   'Max Temp': 84,
#   'Humidity': 68,
#   'Cloudiness': 10,
#   'Wind Speed': 14.7,
#   'Current Description': 'clear sky'},
#  {'City': 'Marsa Matruh',
#   'Country': 'EG',
#   'Lat': 31.3525,
#   'Lng': 27.2453,
#   'Max Temp': 75.97,
#   'Humidity': 68,
#   'Cloudiness': 0,
#   'Wind Speed': 6.8,
#   'Current Description': 'clear sky'},
#  {'City': 'Barabash',
#   'Country': 'RU',
#   'Lat': 43.2,
#   'Lng': 131.4833,
#   'Max Temp': 82.08,
#   'Humidity': 60,
#   'Cloudiness': 95,
#   'Wind Speed': 9.06,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Rize',
#   'Country': 'TR',
#   'Lat': 40.9044,
#   'Lng': 40.8949,
#   'Max Temp': 53.8,
#   'Humidity': 77,
#   'Cloudiness': 12,
#   'Wind Speed': 3.6,
#   'Current Description': 'few clouds'},
#  {'City': 'Joensuu',
#   'Country': 'FI',
#   'Lat': 62.6012,
#   'Lng': 29.7632,
#   'Max Temp': 57.69,
#   'Humidity': 89,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Current Description': 'clear sky'},
#  {'City': 'Ambovombe',
#   'Country': 'MG',
#   'Lat': -25.1667,
#   'Lng': 46.0833,
#   'Max Temp': 61.07,
#   'Humidity': 73,
#   'Cloudiness': 9,
#   'Wind Speed': 12.93,
#   'Current Description': 'light rain'},
#  {'City': 'Nurota',
#   'Country': 'UZ',
#   'Lat': 40.5614,
#   'Lng': 65.6886,
#   'Max Temp': 87.89,
#   'Humidity': 19,
#   'Cloudiness': 0,
#   'Wind Speed': 14.47,
#   'Current Description': 'clear sky'},
#  {'City': 'Malindi',
#   'Country': 'KE',
#   'Lat': -3.2175,
#   'Lng': 40.1191,
#   'Max Temp': 75.15,
#   'Humidity': 75,
#   'Cloudiness': 51,
#   'Wind Speed': 21.52,
#   'Current Description': 'broken clouds'},
#  {'City': 'Westport',
#   'Country': 'US',
#   'Lat': 41.1415,
#   'Lng': -73.3579,
#   'Max Temp': 77.99,
#   'Humidity': 92,
#   'Cloudiness': 90,
#   'Wind Speed': 3,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Waitara',
#   'Country': 'NZ',
#   'Lat': -38.925,
#   'Lng': 174.25,
#   'Max Temp': 57.72,
#   'Humidity': 89,
#   'Cloudiness': 65,
#   'Wind Speed': 14.45,
#   'Current Description': 'broken clouds'},
#  {'City': 'Saint Anthony',
#   'Country': 'US',
#   'Lat': 45.0205,
#   'Lng': -93.218,
#   'Max Temp': 84.92,
#   'Humidity': 46,
#   'Cloudiness': 1,
#   'Wind Speed': 4.61,
#   'Current Description': 'clear sky'},
#  {'City': 'Nabire',
#   'Country': 'ID',
#   'Lat': -3.3667,
#   'Lng': 135.4833,
#   'Max Temp': 87.64,
#   'Humidity': 58,
#   'Cloudiness': 27,
#   'Wind Speed': 3.58,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Sur',
#   'Country': 'OM',
#   'Lat': 22.5667,
#   'Lng': 59.5289,
#   'Max Temp': 89.85,
#   'Humidity': 58,
#   'Cloudiness': 93,
#   'Wind Speed': 8.86,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Sembakung',
#   'Country': 'ID',
#   'Lat': 3.8167,
#   'Lng': 117.25,
#   'Max Temp': 78.73,
#   'Humidity': 68,
#   'Cloudiness': 100,
#   'Wind Speed': 2.37,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Balakhta',
#   'Country': 'RU',
#   'Lat': 55.38,
#   'Lng': 91.6,
#   'Max Temp': 69.94,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 2.01,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Khor',
#   'Country': 'RU',
#   'Lat': 47.8861,
#   'Lng': 134.9464,
#   'Max Temp': 87.78,
#   'Humidity': 52,
#   'Cloudiness': 100,
#   'Wind Speed': 7.65,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Largs',
#   'Country': 'GB',
#   'Lat': 55.7963,
#   'Lng': -4.8634,
#   'Max Temp': 59.45,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 1.01,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kabwe',
#   'Country': 'ZM',
#   'Lat': -14.4469,
#   'Lng': 28.4464,
#   'Max Temp': 46.89,
#   'Humidity': 74,
#   'Cloudiness': 0,
#   'Wind Speed': 8.7,
#   'Current Description': 'clear sky'},
#  {'City': 'Virginia Beach',
#   'Country': 'US',
#   'Lat': 36.8529,
#   'Lng': -75.978,
#   'Max Temp': 82.99,
#   'Humidity': 75,
#   'Cloudiness': 75,
#   'Wind Speed': 10.36,
#   'Current Description': 'broken clouds'},
#  {'City': 'Pemberton',
#   'Country': 'CA',
#   'Lat': 50.3164,
#   'Lng': -122.8027,
#   'Max Temp': 82.04,
#   'Humidity': 42,
#   'Cloudiness': 39,
#   'Wind Speed': 6.69,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Parede',
#   'Country': 'PT',
#   'Lat': 38.6928,
#   'Lng': -9.3541,
#   'Max Temp': 69.3,
#   'Humidity': 82,
#   'Cloudiness': 42,
#   'Wind Speed': 1.01,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Miri',
#   'Country': 'MY',
#   'Lat': 4.4148,
#   'Lng': 114.0089,
#   'Max Temp': 81.57,
#   'Humidity': 88,
#   'Cloudiness': 95,
#   'Wind Speed': 2.42,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Moroni',
#   'Country': 'KM',
#   'Lat': -11.7022,
#   'Lng': 43.2551,
#   'Max Temp': 73.85,
#   'Humidity': 77,
#   'Cloudiness': 29,
#   'Wind Speed': 16.6,
#   'Current Description': 'light rain'},
#  {'City': 'Manaure',
#   'Country': 'CO',
#   'Lat': 11.7751,
#   'Lng': -72.4445,
#   'Max Temp': 79.3,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 7.02,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Sao Jose Da Coroa Grande',
#   'Country': 'BR',
#   'Lat': -8.8978,
#   'Lng': -35.1478,
#   'Max Temp': 73.96,
#   'Humidity': 87,
#   'Cloudiness': 32,
#   'Wind Speed': 11.07,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Ust-Nera',
#   'Country': 'RU',
#   'Lat': 64.5667,
#   'Lng': 143.2,
#   'Max Temp': 52.23,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 4.63,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Spassk-Ryazanskiy',
#   'Country': 'RU',
#   'Lat': 54.4072,
#   'Lng': 40.3806,
#   'Max Temp': 57.11,
#   'Humidity': 61,
#   'Cloudiness': 45,
#   'Wind Speed': 4.47,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Telma',
#   'Country': 'RU',
#   'Lat': 52.6983,
#   'Lng': 103.7097,
#   'Max Temp': 69.01,
#   'Humidity': 45,
#   'Cloudiness': 1,
#   'Wind Speed': 7.7,
#   'Current Description': 'clear sky'},
#  {'City': 'Port Blair',
#   'Country': 'IN',
#   'Lat': 11.6667,
#   'Lng': 92.75,
#   'Max Temp': 83.35,
#   'Humidity': 82,
#   'Cloudiness': 89,
#   'Wind Speed': 19.24,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kailua',
#   'Country': 'US',
#   'Lat': 21.4022,
#   'Lng': -157.7394,
#   'Max Temp': 87.78,
#   'Humidity': 70,
#   'Cloudiness': 75,
#   'Wind Speed': 11.5,
#   'Current Description': 'broken clouds'},
#  {'City': 'Behshahr',
#   'Country': 'IR',
#   'Lat': 36.6923,
#   'Lng': 53.5526,
#   'Max Temp': 80.53,
#   'Humidity': 80,
#   'Cloudiness': 99,
#   'Wind Speed': 6.26,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Dicabisagan',
#   'Country': 'PH',
#   'Lat': 17.0818,
#   'Lng': 122.4157,
#   'Max Temp': 88.14,
#   'Humidity': 61,
#   'Cloudiness': 100,
#   'Wind Speed': 2.28,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ambon',
#   'Country': 'ID',
#   'Lat': -3.6954,
#   'Lng': 128.1814,
#   'Max Temp': 87.94,
#   'Humidity': 66,
#   'Cloudiness': 40,
#   'Wind Speed': 4.61,
#   'Current Description': 'scattered clouds'}]

# %%
len(city_data)
# Out:
# 555

# %%
# Create a city dataframe.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Beloha      MG -25.1667   45.0500     59.00        77           1
# 1  Severo-Kurilsk      RU  50.6789  156.1250     59.34        88          74
# 2       Esperance      AU -33.8667  121.9000     58.84        72           3
# 3           Bijie      CN  27.3125  105.2942     72.84        75           7
# 4          Castro      BR -24.7911  -50.0119     54.99        61           5
# 5         Sorland      NO  67.6670   12.6934     54.14        83         100
# 6      Nikolskoye      RU  59.7035   30.7861     63.81        62          89
# 7         Husavik      IS  66.0449  -17.3389     51.98        65           0
# 8     Yerbogachen      RU  61.2767  108.0108     79.11        41          52
# 9        Hermanus      ZA -34.4187   19.2345     50.81        51         100
#
#    Wind Speed Current Description
# 0       10.74           clear sky
# 1        3.49       broken clouds
# 2       22.48           clear sky
# 3        1.25           clear sky
# 4        3.51           clear sky
# 5        4.59     overcast clouds
# 6        4.34     overcast clouds
# 7       15.14           clear sky
# 8        2.93       broken clouds
# 9        9.51     overcast clouds

# %%
#Export the dataframe to csv file.
city_data_df.to_csv("WeatherPy_Database.csv", index_label="City ID")
